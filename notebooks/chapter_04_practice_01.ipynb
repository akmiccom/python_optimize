# %% [markdown]
# #### 4-1 割引クーポンキャンペーンの効果最大化

# %%
from pulp import LpProblem, LpVariable
from pulp import LpMaximize, LpStatus, lpSum, value
import pandas as pd
import matplotlib.pyplot as plt
from glob import glob
import math
import seaborn as sns
import time

print(plt.rcParams["axes.prop_cycle"])
plt.get_cmap('tab10')
# Out:
# cycler('color', ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf'])

# %%
files = glob('../*/*coupon/*.csv')
dfs = [pd.read_csv(file) for file in files]
for df in dfs:
    display(df.head(3), df.shape)
# Out:
#    customer_id   age_cat freq_cat
# 0            1  age20~34    freq2
# 1            2  age35~49    freq0
# 2            3  age35~49    freq0
# (5000, 3)
#   age_cat freq_cat  segment_id  prob_dm1  prob_dm2  prob_dm3
# 0  age~19    freq0           1      0.07      0.12      0.29
# 1  age~19    freq1           2      0.21      0.30      0.58
# 2  age~19    freq2           3      0.28      0.39      0.74
# (16, 6)

# %%
c_df = dfs[0]
fig, axs = plt.subplots(1, 2, figsize=(6, 2))
for i, c in enumerate(c_df.columns[1:]):
    axs[i].hist(c_df[c])
    axs[i].set_title(c)

# %%
pivot_df = pd.pivot_table(data=c_df, index='age_cat', columns='freq_cat', values='customer_id', aggfunc='count')
pivot_df = pivot_df.reindex(['age~19', 'age20~34', 'age35~49', 'age50~'])
plt.figure(figsize=(6, 3))
sns.heatmap(pivot_df, annot=True, fmt='d', cmap='Blues')
# Out:
# <Axes: xlabel='freq_cat', ylabel='age_cat'>

# %%
p_df = dfs[1]
fig, axs = plt.subplots(1, 3, figsize=(20, 3))
for i, dm_num in enumerate(['prob_dm1', 'prob_dm2', 'prob_dm3']):
    pivot_df = pd.pivot_table(data=p_df, index='age_cat', columns='freq_cat', values=dm_num)
    pivot_df = pivot_df.reindex(['age~19', 'age20~34', 'age35~49', 'age50~'])
    sns.heatmap(pivot_df, vmin=0, vmax=1, annot=True, fmt='.0%', cmap='Blues', ax=axs[i])
    axs[i].set_title(f'Visit_Probability of {dm_num}')
plt.show()

# %%
ID = c_df['customer_id']
DM = [i+1 for i in range(3)]
xim = {(id, dm): LpVariable(name=f'xim({id:03},{dm})', cat='Binary') for dm in DM for id in ID}

# %%
c_p_df = pd.merge(c_df, p_df, on=['age_cat', 'freq_cat'])
c_p_var_df = c_p_df.rename(columns={'prob_dm1': 1, 'prob_dm2': 2, 'prob_dm3': 3})
c_p_var_df = c_p_var_df.melt(id_vars=['customer_id'], value_vars=[1, 2, 3], var_name='dm', value_name='prob')
pim = c_p_var_df.set_index(['customer_id', 'dm'])['prob'].to_dict()

# %%
cost_dm = {1: 0, 2: 1000, 3: 2000}

# %%
SEG = p_df['segment_id']
ns = c_p_df.groupby('segment_id').count()['customer_id'].to_dict()
si = c_p_df.set_index('customer_id')['segment_id'].to_dict()

# %%
m = LpProblem('DiscountCouponProblem01', sense=LpMaximize)

# for id in ID:
#     m += lpSum(xim[id, dm] for dm in DM) == 1

# m += lpSum((pim[id, dm] - pim[id, 1]) * xim[id, dm] for id in ID for dm in DM)

m += lpSum(cost_dm[dm] * pim[id, dm] * xim[id, dm] for id in ID for dm in DM) <= 1000000

# for s in SEG:
#     for dm in DM:
#         m += lpSum(xim[id, dm] for id in ID if si[id] == s) >= 0.1 * ns[s]

m
# Out:
# DiscountCouponProblem01:
# MAXIMIZE
# None
# SUBJECT TO
# _C1: 550 xim(001,2) + 1860 xim(001,3) + 140 xim(002,2) + 660 xim(002,3)
#  + 140 xim(003,2) + 660 xim(003,3) + 120 xim(004,2) + 580 xim(004,3)
#  + 140 xim(005,2) + 660 xim(005,3) + 430 xim(006,2) + 1440 xim(006,3)
#  + 300 xim(007,2) + 1160 xim(007,3) + 120 xim(008,2) + 580 xim(008,3)
#  + 140 xim(009,2) + 660 xim(009,3) + 430 xim(010,2) + 1440 xim(010,3)
#  + 350 xim(011,2) + 1340 xim(011,3) + 350 xim(012,2) + 1340 xim(012,3)
#  + 350 xim(013,2) + 1340 xim(013,3) + 450 xim(014,2) + 1720 xim(014,3)
#  + 140 xim(015,2) + 660 xim(015,3) + 430 xim(016,2) + 1440 xim(016,3)
#  + 140 xim(017,2) + 660 xim(017,3) + 130 xim(018,2) + 640 xim(018,3)
#  + 430 xim(019,2) + 1440 xim(019,3) + 300 xim(020,2) + 1160 xim(020,3)
#  + 350 xim(021,2) + 1340 xim(021,3) + 430 xim(022,2) + 1440 xim(022,3)
#  + 350 xim(023,2) + 1340 xim(023,3) + 350 xim(024,2) + 1340 xim(024,3)
#  + 300 xim(025,2) + 1160 xim(025,3) + 140 xim(026,2) + 660 xim(026,3)
#  + 630 xim(027,2) + 1880 xim(027,3) + 450 xim(028,2) + 1540 xim(028,3)
#  + 130 xim(029,2) + 640 xim(029,3) + 170 xim(030,2) + 740 xim(030,3)
#  + 140 xim(031,2) + 660 xim(031,3) + 120 xim(032,2) + 580 xim(032,3)
#  + 170 xim(033,2) + 740 xim(033,3) + 120 xim(034,2) + 580 xim(034,3)
#  + 140 xim(035,2) + 660 xim(035,3) + 630 xim(036,2) + 1880 xim(036,3)
#  + 140 xim(037,2) + 660 xim(037,3) + 630 xim(038,2) + 1880 xim(038,3)
#  + 430 xim(039,2) + 1440 xim(039,3) + 170 xim(040,2) + 740 xim(040,3)
#  + 130 xim(041,2) + 640 xim(041,3) + 140 xim(042,2) + 660 xim(042,3)
#  + 350 xim(043,2) + 1340 xim(043,3) + 430 xim(044,2) + 1440 xim(044,3)
#  + 130 xim(045,2) + 640 xim(045,3) + 630 xim(046,2) + 1880 xim(046,3)
#  + 170 xim(047,2) + 740 xim(047,3) + 300 xim(048,2) + 1160 xim(048,3)
#  + 130 xim(049,2) + 640 xim(049,3) + 330 xim(050,2) + 1300 xim(050,3)
#  + 350 xim(051,2) + 1340 xim(051,3) + 350 xim(052,2) + 1340 xim(052,3)
#  + 140 xim(053,2) + 660 xim(053,3) + 350 xim(054,2) + 1340 xim(054,3)
#  + 350 xim(055,2) + 1340 xim(055,3) + 140 xim(056,2) + 660 xim(056,3)
#  + 350 xim(057,2) + 1340 xim(057,3) + 140 xim(058,2) + 660 xim(058,3)
#  + 170 xim(059,2) + 740 xim(059,3) + 140 xim(060,2) + 660 xim(060,3)
#  + 300 xim(061,2) + 1160 xim(061,3) + 170 xim(062,2) + 740 xim(062,3)
#  + 170 xim(063,2) + 740 xim(063,3) + 140 xim(064,2) + 660 xim(064,3)
#  + 300 xim(065,2) + 1160 xim(065,3) + 430 xim(066,2) + 1440 xim(066,3)
#  + 130 xim(067,2) + 640 xim(067,3) + 350 xim(068,2) + 1340 xim(068,3)
#  + 300 xim(069,2) + 1160 xim(069,3) + 350 xim(070,2) + 1340 xim(070,3)
#  + 630 xim(071,2) + 1880 xim(071,3) + 420 xim(072,2) + 1680 xim(072,3)
#  + 350 xim(073,2) + 1340 xim(073,3) + 170 xim(074,2) + 740 xim(074,3)
#  + 490 xim(075,2) + 1760 xim(075,3) + 140 xim(076,2) + 660 xim(076,3)
#  + 350 xim(077,2) + 1340 xim(077,3) + 170 xim(078,2) + 740 xim(078,3)
#  + 350 xim(079,2) + 1340 xim(079,3) + 430 xim(080,2) + 1440 xim(080,3)
#  + 490 xim(081,2) + 1760 xim(081,3) + 130 xim(082,2) + 640 xim(082,3)
#  + 140 xim(083,2) + 660 xim(083,3) + 450 xim(084,2) + 1720 xim(084,3)
#  + 430 xim(085,2) + 1440 xim(085,3) + 520 xim(086,2) + 1780 xim(086,3)
#  + 520 xim(087,2) + 1780 xim(087,3) + 450 xim(088,2) + 1720 xim(088,3)
#  + 430 xim(089,2) + 1440 xim(089,3) + 490 xim(090,2) + 1760 xim(090,3)
#  + 170 xim(091,2) + 740 xim(091,3) + 390 xim(092,2) + 1480 xim(092,3)
#  + 450 xim(093,2) + 1540 xim(093,3) + 430 xim(094,2) + 1440 xim(094,3)
#  + 170 xim(095,2) + 740 xim(095,3) + 120 xim(096,2) + 580 xim(096,3)
#  + 520 xim(097,2) + 1780 xim(097,3) + 130 xim(098,2) + 640 xim(098,3)
#  + 350 xim(099,2) + 1340 xim(099,3) + 170 xim(100,2) + 740 xim(100,3)
#  + 130 xim(1000,2) + 640 xim(1000,3) + 130 xim(1001,2) + 640 xim(1001,3)
#  + 140 xim(1002,2) + 660 xim(1002,3) + 430 xim(1003,2) + 1440 xim(1003,3)
#  + 140 xim(1004,2) + 660 xim(1004,3) + 430 xim(1005,2) + 1440 xim(1005,3)
#  + 140 xim(1006,2) + 660 xim(1006,3) + 140 xim(1007,2) + 660 xim(1007,3)
#  + 140 xim(1008,2) + 660 xim(1008,3) + 170 xim(1009,2) + 740 xim(1009,3)
#  + 170 xim(101,2) + 740 xim(101,3) + 350 xim(1010,2) + 1340 xim(1010,3)
#  + 330 xim(1011,2) + 1300 xim(1011,3) + 520 xim(1012,2) + 1780 xim(1012,3)
#  + 120 xim(1013,2) + 580 xim(1013,3) + 350 xim(1014,2) + 1340 xim(1014,3)
#  + 430 xim(1015,2) + 1440 xim(1015,3) + 330 xim(1016,2) + 1300 xim(1016,3)
#  + 350 xim(1017,2) + 1340 xim(1017,3) + 140 xim(1018,2) + 660 xim(1018,3)
#  + 430 xim(1019,2) + 1440 xim(1019,3) + 140 xim(102,2) + 660 xim(102,3)
#  + 350 xim(1020,2) + 1340 xim(1020,3) + 630 xim(1021,2) + 1880 xim(1021,3)
#  + 430 xim(1022,2) + 1440 xim(1022,3) + 170 xim(1023,2) + 740 xim(1023,3)
#  + 520 xim(1024,2) + 1780 xim(1024,3) + 420 xim(1025,2) + 1680 xim(1025,3)
#  + 550 xim(1026,2) + 1860 xim(1026,3) + 170 xim(1027,2) + 740 xim(1027,3)
#  + 430 xim(1028,2) + 1440 xim(1028,3) + 420 xim(1029,2) + 1680 xim(1029,3)
#  + 450 xim(103,2) + 1540 xim(103,3) + 140 xim(1030,2) + 660 xim(1030,3)
#  + 350 xim(1031,2) + 1340 xim(1031,3) + 520 xim(1032,2) + 1780 xim(1032,3)
#  + 430 xim(1033,2) + 1440 xim(1033,3) + 390 xim(1034,2) + 1480 xim(1034,3)
#  + 350 xim(1035,2) + 1340 xim(1035,3) + 300 xim(1036,2) + 1160 xim(1036,3)
#  + 170 xim(1037,2) + 740 xim(1037,3) + 170 xim(1038,2) + 740 xim(1038,3)
#  + 130 xim(1039,2) + 640 xim(1039,3) + 450 xim(104,2) + 1540 xim(104,3)
#  + 130 xim(1040,2) + 640 xim(1040,3) + 430 xim(1041,2) + 1440 xim(1041,3)
#  + 430 xim(1042,2) + 1440 xim(1042,3) + 300 xim(1043,2) + 1160 xim(1043,3)
#  + 330 xim(1044,2) + 1300 xim(1044,3) + 450 xim(1045,2) + 1720 xim(1045,3)
#  + 170 xim(1046,2) + 740 xim(1046,3) + 140 xim(1047,2) + 660 xim(1047,3)
#  + 300 xim(1048,2) + 1160 xim(1048,3) + 170 xim(1049,2) + 740 xim(1049,3)
#  + 130 xim(105,2) + 640 xim(105,3) + 630 xim(1050,2) + 1880 xim(1050,3)
#  + 430 xim(1051,2) + 1440 xim(1051,3) + 170 xim(1052,2) + 740 xim(1052,3)
#  + 430 xim(1053,2) + 1440 xim(1053,3) + 330 xim(1054,2) + 1300 xim(1054,3)
#  + 170 xim(1055,2) + 740 xim(1055,3) + 330 xim(1056,2) + 1300 xim(1056,3)
#  + 490 xim(1057,2) + 1760 xim(1057,3) + 350 xim(1058,2) + 1340 xim(1058,3)
#  + 390 xim(1059,2) + 1480 xim(1059,3) + 350 xim(106,2) + 1340 xim(106,3)
#  + 520 xim(1060,2) + 1780 xim(1060,3) + 170 xim(1061,2) + 740 xim(1061,3)
#  + 630 xim(1062,2) + 1880 xim(1062,3) + 350 xim(1063,2) + 1340 xim(1063,3)
#  + 130 xim(1064,2) + 640 xim(1064,3) + 350 xim(1065,2) + 1340 xim(1065,3)
#  + 430 xim(1066,2) + 1440 xim(1066,3) + 350 xim(1067,2) + 1340 xim(1067,3)
#  + 140 xim(1068,2) + 660 xim(1068,3) + 550 xim(1069,2) + 1860 xim(1069,3)
#  + 350 xim(107,2) + 1340 xim(107,3) + 120 xim(1070,2) + 580 xim(1070,3)
#  + 430 xim(1071,2) + 1440 xim(1071,3) + 520 xim(1072,2) + 1780 xim(1072,3)
#  + 140 xim(1073,2) + 660 xim(1073,3) + 130 xim(1074,2) + 640 xim(1074,3)
#  + 390 xim(1075,2) + 1480 xim(1075,3) + 390 xim(1076,2) + 1480 xim(1076,3)
#  + 490 xim(1077,2) + 1760 xim(1077,3) + 520 xim(1078,2) + 1780 xim(1078,3)
#  + 520 xim(1079,2) + 1780 xim(1079,3) + 300 xim(108,2) + 1160 xim(108,3)
#  + 170 xim(1080,2) + 740 xim(1080,3) + 430 xim(1081,2) + 1440 xim(1081,3)
#  + 430 xim(1082,2) + 1440 xim(1082,3) + 430 xim(1083,2) + 1440 xim(1083,3)
#  + 140 xim(1084,2) + 660 xim(1084,3) + 130 xim(1085,2) + 640 xim(1085,3)
#  + 450 xim(1086,2) + 1720 xim(1086,3) + 130 xim(1087,2) + 640 xim(1087,3)
#  + 140 xim(1088,2) + 660 xim(1088,3) + 630 xim(1089,2) + 1880 xim(1089,3)
#  + 140 xim(109,2) + 660 xim(109,3) + 420 xim(1090,2) + 1680 xim(1090,3)
#  + 120 xim(1091,2) + 580 xim(1091,3) + 120 xim(1092,2) + 580 xim(1092,3)
#  + 170 xim(1093,2) + 740 xim(1093,3) + 630 xim(1094,2) + 1880 xim(1094,3)
#  + 430 xim(1095,2) + 1440 xim(1095,3) + 450 xim(1096,2) + 1540 xim(1096,3)
#  + 630 xim(1097,2) + 1880 xim(1097,3) + 430 xim(1098,2) + 1440 xim(1098,3)
#  + 130 xim(1099,2) + 640 xim(1099,3) + 520 xim(110,2) + 1780 xim(110,3)
#  + 130 xim(1100,2) + 640 xim(1100,3) + 170 xim(1101,2) + 740 xim(1101,3)
#  + 450 xim(1102,2) + 1720 xim(1102,3) + 330 xim(1103,2) + 1300 xim(1103,3)
#  + 520 xim(1104,2) + 1780 xim(1104,3) + 330 xim(1105,2) + 1300 xim(1105,3)
#  + 630 xim(1106,2) + 1880 xim(1106,3) + 520 xim(1107,2) + 1780 xim(1107,3)
#  + 330 xim(1108,2) + 1300 xim(1108,3) + 350 xim(1109,2) + 1340 xim(1109,3)
#  + 430 xim(111,2) + 1440 xim(111,3) + 520 xim(1110,2) + 1780 xim(1110,3)
#  + 120 xim(1111,2) + 580 xim(1111,3) + 350 xim(1112,2) + 1340 xim(1112,3)
#  + 450 xim(1113,2) + 1540 xim(1113,3) + 450 xim(1114,2) + 1720 xim(1114,3)
#  + 120 xim(1115,2) + 580 xim(1115,3) + 330 xim(1116,2) + 1300 xim(1116,3)
#  + 130 xim(1117,2) + 640 xim(1117,3) + 550 xim(1118,2) + 1860 xim(1118,3)
#  + 350 xim(1119,2) + 1340 xim(1119,3) + 140 xim(112,2) + 660 xim(112,3)
#  + 170 xim(1120,2) + 740 xim(1120,3) + 390 xim(1121,2) + 1480 xim(1121,3)
#  + 450 xim(1122,2) + 1540 xim(1122,3) + 140 xim(1123,2) + 660 xim(1123,3)
#  + 140 xim(1124,2) + 660 xim(1124,3) + 350 xim(1125,2) + 1340 xim(1125,3)
#  + 140 xim(1126,2) + 660 xim(1126,3) + 630 xim(1127,2) + 1880 xim(1127,3)
#  + 300 xim(1128,2) + 1160 xim(1128,3) + 430 xim(1129,2) + 1440 xim(1129,3)
#  + 450 xim(113,2) + 1720 xim(113,3) + 300 xim(1130,2) + 1160 xim(1130,3)
#  + 550 xim(1131,2) + 1860 xim(1131,3) + 430 xim(1132,2) + 1440 xim(1132,3)
#  + 420 xim(1133,2) + 1680 xim(1133,3) + 170 xim(1134,2) + 740 xim(1134,3)
#  + 140 xim(1135,2) + 660 xim(1135,3) + 170 xim(1136,2) + 740 xim(1136,3)
#  + 630 xim(1137,2) + 1880 xim(1137,3) + 300 xim(1138,2) + 1160 xim(1138,3)
#  + 170 xim(1139,2) + 740 xim(1139,3) + 520 xim(114,2) + 1780 xim(114,3)
#  + 170 xim(1140,2) + 740 xim(1140,3) + 630 xim(1141,2) + 1880 xim(1141,3)
#  + 130 xim(1142,2) + 640 xim(1142,3) + 120 xim(1143,2) + 580 xim(1143,3)
#  + 430 xim(1144,2) + 1440 xim(1144,3) + 140 xim(1145,2) + 660 xim(1145,3)
#  + 350 xim(1146,2) + 1340 xim(1146,3) + 430 xim(1147,2) + 1440 xim(1147,3)
#  + 120 xim(1148,2) + 580 xim(1148,3) + 350 xim(1149,2) + 1340 xim(1149,3)
#  + 140 xim(115,2) + 660 xim(115,3) + 430 xim(1150,2) + 1440 xim(1150,3)
#  + 300 xim(1151,2) + 1160 xim(1151,3) + 450 xim(1152,2) + 1720 xim(1152,3)
#  + 450 xim(1153,2) + 1720 xim(1153,3) + 450 xim(1154,2) + 1540 xim(1154,3)
#  + 140 xim(1155,2) + 660 xim(1155,3) + 130 xim(1156,2) + 640 xim(1156,3)
#  + 130 xim(1157,2) + 640 xim(1157,3) + 420 xim(1158,2) + 1680 xim(1158,3)
#  + 350 xim(1159,2) + 1340 xim(1159,3) + 140 xim(116,2) + 660 xim(116,3)
#  + 170 xim(1160,2) + 740 xim(1160,3) + 170 xim(1161,2) + 740 xim(1161,3)
#  + 170 xim(1162,2) + 740 xim(1162,3) + 350 xim(1163,2) + 1340 xim(1163,3)
#  + 170 xim(1164,2) + 740 xim(1164,3) + 520 xim(1165,2) + 1780 xim(1165,3)
#  + 300 xim(1166,2) + 1160 xim(1166,3) + 350 xim(1167,2) + 1340 xim(1167,3)
#  + 630 xim(1168,2) + 1880 xim(1168,3) + 350 xim(1169,2) + 1340 xim(1169,3)
#  + 430 xim(117,2) + 1440 xim(117,3) + 140 xim(1170,2) + 660 xim(1170,3)
#  + 330 xim(1171,2) + 1300 xim(1171,3) + 130 xim(1172,2) + 640 xim(1172,3)
#  + 140 xim(1173,2) + 660 xim(1173,3) + 140 xim(1174,2) + 660 xim(1174,3)
#  + 130 xim(1175,2) + 640 xim(1175,3) + 350 xim(1176,2) + 1340 xim(1176,3)
#  + 350 xim(1177,2) + 1340 xim(1177,3) + 450 xim(1178,2) + 1540 xim(1178,3)
#  + 120 xim(1179,2) + 580 xim(1179,3) + 170 xim(118,2) + 740 xim(118,3)
#  + 430 xim(1180,2) + 1440 xim(1180,3) + 300 xim(1181,2) + 1160 xim(1181,3)
#  + 430 xim(1182,2) + 1440 xim(1182,3) + 330 xim(1183,2) + 1300 xim(1183,3)
#  + 170 xim(1184,2) + 740 xim(1184,3) + 170 xim(1185,2) + 740 xim(1185,3)
#  + 120 xim(1186,2) + 580 xim(1186,3) + 430 xim(1187,2) + 1440 xim(1187,3)
#  + 520 xim(1188,2) + 1780 xim(1188,3) + 300 xim(1189,2) + 1160 xim(1189,3)
#  + 430 xim(119,2) + 1440 xim(119,3) + 350 xim(1190,2) + 1340 xim(1190,3)
#  + 140 xim(1191,2) + 660 xim(1191,3) + 140 xim(1192,2) + 660 xim(1192,3)
#  + 630 xim(1193,2) + 1880 xim(1193,3) + 350 xim(1194,2) + 1340 xim(1194,3)
#  + 170 xim(1195,2) + 740 xim(1195,3) + 140 xim(1196,2) + 660 xim(1196,3)
#  + 550 xim(1197,2) + 1860 xim(1197,3) + 430 xim(1198,2) + 1440 xim(1198,3)
#  + 430 xim(1199,2) + 1440 xim(1199,3) + 140 xim(120,2) + 660 xim(120,3)
#  + 130 xim(1200,2) + 640 xim(1200,3) + 140 xim(1201,2) + 660 xim(1201,3)
#  + 550 xim(1202,2) + 1860 xim(1202,3) + 140 xim(1203,2) + 660 xim(1203,3)
#  + 120 xim(1204,2) + 580 xim(1204,3) + 430 xim(1205,2) + 1440 xim(1205,3)
#  + 130 xim(1206,2) + 640 xim(1206,3) + 140 xim(1207,2) + 660 xim(1207,3)
#  + 490 xim(1208,2) + 1760 xim(1208,3) + 300 xim(1209,2) + 1160 xim(1209,3)
#  + 430 xim(121,2) + 1440 xim(121,3) + 350 xim(1210,2) + 1340 xim(1210,3)
#  + 550 xim(1211,2) + 1860 xim(1211,3) + 140 xim(1212,2) + 660 xim(1212,3)
#  + 630 xim(1213,2) + 1880 xim(1213,3) + 350 xim(1214,2) + 1340 xim(1214,3)
#  + 120 xim(1215,2) + 580 xim(1215,3) + 330 xim(1216,2) + 1300 xim(1216,3)
#  + 140 xim(1217,2) + 660 xim(1217,3) + 170 xim(1218,2) + 740 xim(1218,3)
#  + 350 xim(1219,2) + 1340 xim(1219,3) + 140 xim(122,2) + 660 xim(122,3)
#  + 490 xim(1220,2) + 1760 xim(1220,3) + 430 xim(1221,2) + 1440 xim(1221,3)
#  + 130 xim(1222,2) + 640 xim(1222,3) + 430 xim(1223,2) + 1440 xim(1223,3)
#  + 140 xim(1224,2) + 660 xim(1224,3) + 520 xim(1225,2) + 1780 xim(1225,3)
#  + 350 xim(1226,2) + 1340 xim(1226,3) + 430 xim(1227,2) + 1440 xim(1227,3)
#  + 430 xim(1228,2) + 1440 xim(1228,3) + 420 xim(1229,2) + 1680 xim(1229,3)
#  + 140 xim(123,2) + 660 xim(123,3) + 130 xim(1230,2) + 640 xim(1230,3)
#  + 350 xim(1231,2) + 1340 xim(1231,3) + 430 xim(1232,2) + 1440 xim(1232,3)
#  + 140 xim(1233,2) + 660 xim(1233,3) + 350 xim(1234,2) + 1340 xim(1234,3)
#  + 140 xim(1235,2) + 660 xim(1235,3) + 140 xim(1236,2) + 660 xim(1236,3)
#  + 350 xim(1237,2) + 1340 xim(1237,3) + 490 xim(1238,2) + 1760 xim(1238,3)
#  + 350 xim(1239,2) + 1340 xim(1239,3) + 140 xim(124,2) + 660 xim(124,3)
#  + 350 xim(1240,2) + 1340 xim(1240,3) + 450 xim(1241,2) + 1720 xim(1241,3)
#  + 170 xim(1242,2) + 740 xim(1242,3) + 170 xim(1243,2) + 740 xim(1243,3)
#  + 300 xim(1244,2) + 1160 xim(1244,3) + 350 xim(1245,2) + 1340 xim(1245,3)
#  + 130 xim(1246,2) + 640 xim(1246,3) + 520 xim(1247,2) + 1780 xim(1247,3)
#  + 430 xim(1248,2) + 1440 xim(1248,3) + 350 xim(1249,2) + 1340 xim(1249,3)
#  + 490 xim(125,2) + 1760 xim(125,3) + 350 xim(1250,2) + 1340 xim(1250,3)
#  + 170 xim(1251,2) + 740 xim(1251,3) + 430 xim(1252,2) + 1440 xim(1252,3)
#  + 520 xim(1253,2) + 1780 xim(1253,3) + 430 xim(1254,2) + 1440 xim(1254,3)
#  + 130 xim(1255,2) + 640 xim(1255,3) + 520 xim(1256,2) + 1780 xim(1256,3)
#  + 170 xim(1257,2) + 740 xim(1257,3) + 170 xim(1258,2) + 740 xim(1258,3)
#  + 170 xim(1259,2) + 740 xim(1259,3) + 140 xim(126,2) + 660 xim(126,3)
#  + 170 xim(1260,2) + 740 xim(1260,3) + 120 xim(1261,2) + 580 xim(1261,3)
#  + 140 xim(1262,2) + 660 xim(1262,3) + 520 xim(1263,2) + 1780 xim(1263,3)
#  + 550 xim(1264,2) + 1860 xim(1264,3) + 350 xim(1265,2) + 1340 xim(1265,3)
#  + 330 xim(1266,2) + 1300 xim(1266,3) + 170 xim(1267,2) + 740 xim(1267,3)
#  + 350 xim(1268,2) + 1340 xim(1268,3) + 130 xim(1269,2) + 640 xim(1269,3)
#  + 140 xim(127,2) + 660 xim(127,3) + 170 xim(1270,2) + 740 xim(1270,3)
#  + 140 xim(1271,2) + 660 xim(1271,3) + 350 xim(1272,2) + 1340 xim(1272,3)
#  + 140 xim(1273,2) + 660 xim(1273,3) + 170 xim(1274,2) + 740 xim(1274,3)
#  + 550 xim(1275,2) + 1860 xim(1275,3) + 350 xim(1276,2) + 1340 xim(1276,3)
#  + 130 xim(1277,2) + 640 xim(1277,3) + 430 xim(1278,2) + 1440 xim(1278,3)
#  + 330 xim(1279,2) + 1300 xim(1279,3) + 450 xim(128,2) + 1720 xim(128,3)
#  + 140 xim(1280,2) + 660 xim(1280,3) + 130 xim(1281,2) + 640 xim(1281,3)
#  + 140 xim(1282,2) + 660 xim(1282,3) + 140 xim(1283,2) + 660 xim(1283,3)
#  + 330 xim(1284,2) + 1300 xim(1284,3) + 350 xim(1285,2) + 1340 xim(1285,3)
#  + 120 xim(1286,2) + 580 xim(1286,3) + 140 xim(1287,2) + 660 xim(1287,3)
#  + 170 xim(1288,2) + 740 xim(1288,3) + 170 xim(1289,2) + 740 xim(1289,3)
#  + 630 xim(129,2) + 1880 xim(129,3) + 170 xim(1290,2) + 740 xim(1290,3)
#  + 630 xim(1291,2) + 1880 xim(1291,3) + 330 xim(1292,2) + 1300 xim(1292,3)
#  + 330 xim(1293,2) + 1300 xim(1293,3) + 450 xim(1294,2) + 1720 xim(1294,3)
#  + 120 xim(1295,2) + 580 xim(1295,3) + 430 xim(1296,2) + 1440 xim(1296,3)
#  + 630 xim(1297,2) + 1880 xim(1297,3) + 120 xim(1298,2) + 580 xim(1298,3)
#  + 140 xim(1299,2) + 660 xim(1299,3) + 330 xim(130,2) + 1300 xim(130,3)
#  + 120 xim(1300,2) + 580 xim(1300,3) + 140 xim(1301,2) + 660 xim(1301,3)
#  + 490 xim(1302,2) + 1760 xim(1302,3) + 300 xim(1303,2) + 1160 xim(1303,3)
#  + 490 xim(1304,2) + 1760 xim(1304,3) + 430 xim(1305,2) + 1440 xim(1305,3)
#  + 300 xim(1306,2) + 1160 xim(1306,3) + 130 xim(1307,2) + 640 xim(1307,3)
#  + 140 xim(1308,2) + 660 xim(1308,3) + 430 xim(1309,2) + 1440 xim(1309,3)
#  + 130 xim(131,2) + 640 xim(131,3) + 140 xim(1310,2) + 660 xim(1310,3)
#  + 630 xim(1311,2) + 1880 xim(1311,3) + 140 xim(1312,2) + 660 xim(1312,3)
#  + 140 xim(1313,2) + 660 xim(1313,3) + 330 xim(1314,2) + 1300 xim(1314,3)
#  + 140 xim(1315,2) + 660 xim(1315,3) + 350 xim(1316,2) + 1340 xim(1316,3)
#  + 170 xim(1317,2) + 740 xim(1317,3) + 350 xim(1318,2) + 1340 xim(1318,3)
#  + 520 xim(1319,2) + 1780 xim(1319,3) + 350 xim(132,2) + 1340 xim(132,3)
#  + 450 xim(1320,2) + 1720 xim(1320,3) + 430 xim(1321,2) + 1440 xim(1321,3)
#  + 170 xim(1322,2) + 740 xim(1322,3) + 300 xim(1323,2) + 1160 xim(1323,3)
#  + 350 xim(1324,2) + 1340 xim(1324,3) + 140 xim(1325,2) + 660 xim(1325,3)
#  + 350 xim(1326,2) + 1340 xim(1326,3) + 350 xim(1327,2) + 1340 xim(1327,3)
#  + 630 xim(1328,2) + 1880 xim(1328,3) + 450 xim(1329,2) + 1540 xim(1329,3)
#  + 140 xim(133,2) + 660 xim(133,3) + 520 xim(1330,2) + 1780 xim(1330,3)
#  + 630 xim(1331,2) + 1880 xim(1331,3) + 350 xim(1332,2) + 1340 xim(1332,3)
#  + 520 xim(1333,2) + 1780 xim(1333,3) + 420 xim(1334,2) + 1680 xim(1334,3)
#  + 430 xim(1335,2) + 1440 xim(1335,3) + 520 xim(1336,2) + 1780 xim(1336,3)
#  + 170 xim(1337,2) + 740 xim(1337,3) + 120 xim(1338,2) + 580 xim(1338,3)
#  + 520 xim(1339,2) + 1780 xim(1339,3) + 430 xim(134,2) + 1440 xim(134,3)
#  + 520 xim(1340,2) + 1780 xim(1340,3) + 170 xim(1341,2) + 740 xim(1341,3)
#  + 140 xim(1342,2) + 660 xim(1342,3) + 450 xim(1343,2) + 1720 xim(1343,3)
#  + 490 xim(1344,2) + 1760 xim(1344,3) + 430 xim(1345,2) + 1440 xim(1345,3)
#  + 350 xim(1346,2) + 1340 xim(1346,3) + 130 xim(1347,2) + 640 xim(1347,3)
#  + 140 xim(1348,2) + 660 xim(1348,3) + 120 xim(1349,2) + 580 xim(1349,3)
#  + 450 xim(135,2) + 1540 xim(135,3) + 170 xim(1350,2) + 740 xim(1350,3)
#  + 140 xim(1351,2) + 660 xim(1351,3) + 120 xim(1352,2) + 580 xim(1352,3)
#  + 140 xim(1353,2) + 660 xim(1353,3) + 330 xim(1354,2) + 1300 xim(1354,3)
#  + 630 xim(1355,2) + 1880 xim(1355,3) + 170 xim(1356,2) + 740 xim(1356,3)
#  + 350 xim(1357,2) + 1340 xim(1357,3) + 630 xim(1358,2) + 1880 xim(1358,3)
#  + 450 xim(1359,2) + 1720 xim(1359,3) + 120 xim(136,2) + 580 xim(136,3)
#  + 350 xim(1360,2) + 1340 xim(1360,3) + 130 xim(1361,2) + 640 xim(1361,3)
#  + 330 xim(1362,2) + 1300 xim(1362,3) + 120 xim(1363,2) + 580 xim(1363,3)
#  + 330 xim(1364,2) + 1300 xim(1364,3) + 350 xim(1365,2) + 1340 xim(1365,3)
#  + 490 xim(1366,2) + 1760 xim(1366,3) + 130 xim(1367,2) + 640 xim(1367,3)
#  + 170 xim(1368,2) + 740 xim(1368,3) + 430 xim(1369,2) + 1440 xim(1369,3)
#  + 140 xim(137,2) + 660 xim(137,3) + 520 xim(1370,2) + 1780 xim(1370,3)
#  + 450 xim(1371,2) + 1540 xim(1371,3) + 140 xim(1372,2) + 660 xim(1372,3)
#  + 630 xim(1373,2) + 1880 xim(1373,3) + 350 xim(1374,2) + 1340 xim(1374,3)
#  + 330 xim(1375,2) + 1300 xim(1375,3) + 140 xim(1376,2) + 660 xim(1376,3)
#  + 140 xim(1377,2) + 660 xim(1377,3) + 350 xim(1378,2) + 1340 xim(1378,3)
#  + 130 xim(1379,2) + 640 xim(1379,3) + 350 xim(138,2) + 1340 xim(138,3)
#  + 300 xim(1380,2) + 1160 xim(1380,3) + 130 xim(1381,2) + 640 xim(1381,3)
#  + 130 xim(1382,2) + 640 xim(1382,3) + 170 xim(1383,2) + 740 xim(1383,3)
#  + 350 xim(1384,2) + 1340 xim(1384,3) + 130 xim(1385,2) + 640 xim(1385,3)
#  + 170 xim(1386,2) + 740 xim(1386,3) + 390 xim(1387,2) + 1480 xim(1387,3)
#  + 300 xim(1388,2) + 1160 xim(1388,3) + 130 xim(1389,2) + 640 xim(1389,3)
#  + 430 xim(139,2) + 1440 xim(139,3) + 130 xim(1390,2) + 640 xim(1390,3)
#  + 350 xim(1391,2) + 1340 xim(1391,3) + 630 xim(1392,2) + 1880 xim(1392,3)
#  + 630 xim(1393,2) + 1880 xim(1393,3) + 330 xim(1394,2) + 1300 xim(1394,3)
#  + 170 xim(1395,2) + 740 xim(1395,3) + 350 xim(1396,2) + 1340 xim(1396,3)
#  + 300 xim(1397,2) + 1160 xim(1397,3) + 140 xim(1398,2) + 660 xim(1398,3)
#  + 430 xim(1399,2) + 1440 xim(1399,3) + 140 xim(140,2) + 660 xim(140,3)
#  + 140 xim(1400,2) + 660 xim(1400,3) + 450 xim(1401,2) + 1720 xim(1401,3)
#  + 330 xim(1402,2) + 1300 xim(1402,3) + 140 xim(1403,2) + 660 xim(1403,3)
#  + 550 xim(1404,2) + 1860 xim(1404,3) + 170 xim(1405,2) + 740 xim(1405,3)
#  + 140 xim(1406,2) + 660 xim(1406,3) + 430 xim(1407,2) + 1440 xim(1407,3)
#  + 140 xim(1408,2) + 660 xim(1408,3) + 520 xim(1409,2) + 1780 xim(1409,3)
#  + 490 xim(141,2) + 1760 xim(141,3) + 130 xim(1410,2) + 640 xim(1410,3)
#  + 490 xim(1411,2) + 1760 xim(1411,3) + 630 xim(1412,2) + 1880 xim(1412,3)
#  + 170 xim(1413,2) + 740 xim(1413,3) + 140 xim(1414,2) + 660 xim(1414,3)
#  + 330 xim(1415,2) + 1300 xim(1415,3) + 130 xim(1416,2) + 640 xim(1416,3)
#  + 130 xim(1417,2) + 640 xim(1417,3) + 450 xim(1418,2) + 1540 xim(1418,3)
#  + 170 xim(1419,2) + 740 xim(1419,3) + 170 xim(142,2) + 740 xim(142,3)
#  + 430 xim(1420,2) + 1440 xim(1420,3) + 130 xim(1421,2) + 640 xim(1421,3)
#  + 350 xim(1422,2) + 1340 xim(1422,3) + 140 xim(1423,2) + 660 xim(1423,3)
#  + 520 xim(1424,2) + 1780 xim(1424,3) + 140 xim(1425,2) + 660 xim(1425,3)
#  + 450 xim(1426,2) + 1720 xim(1426,3) + 350 xim(1427,2) + 1340 xim(1427,3)
#  + 170 xim(1428,2) + 740 xim(1428,3) + 520 xim(1429,2) + 1780 xim(1429,3)
#  + 170 xim(143,2) + 740 xim(143,3) + 350 xim(1430,2) + 1340 xim(1430,3)
#  + 450 xim(1431,2) + 1720 xim(1431,3) + 450 xim(1432,2) + 1720 xim(1432,3)
#  + 430 xim(1433,2) + 1440 xim(1433,3) + 520 xim(1434,2) + 1780 xim(1434,3)
#  + 120 xim(1435,2) + 580 xim(1435,3) + 170 xim(1436,2) + 740 xim(1436,3)
#  + 520 xim(1437,2) + 1780 xim(1437,3) + 170 xim(1438,2) + 740 xim(1438,3)
#  + 130 xim(1439,2) + 640 xim(1439,3) + 140 xim(144,2) + 660 xim(144,3)
#  + 130 xim(1440,2) + 640 xim(1440,3) + 300 xim(1441,2) + 1160 xim(1441,3)
#  + 350 xim(1442,2) + 1340 xim(1442,3) + 450 xim(1443,2) + 1720 xim(1443,3)
#  + 520 xim(1444,2) + 1780 xim(1444,3) + 630 xim(1445,2) + 1880 xim(1445,3)
#  + 170 xim(1446,2) + 740 xim(1446,3) + 520 xim(1447,2) + 1780 xim(1447,3)
#  + 330 xim(1448,2) + 1300 xim(1448,3) + 450 xim(1449,2) + 1720 xim(1449,3)
#  + 170 xim(145,2) + 740 xim(145,3) + 450 xim(1450,2) + 1720 xim(1450,3)
#  + 350 xim(1451,2) + 1340 xim(1451,3) + 350 xim(1452,2) + 1340 xim(1452,3)
#  + 550 xim(1453,2) + 1860 xim(1453,3) + 430 xim(1454,2) + 1440 xim(1454,3)
#  + 140 xim(1455,2) + 660 xim(1455,3) + 120 xim(1456,2) + 580 xim(1456,3)
#  + 520 xim(1457,2) + 1780 xim(1457,3) + 170 xim(1458,2) + 740 xim(1458,3)
#  + 630 xim(1459,2) + 1880 xim(1459,3) + 140 xim(146,2) + 660 xim(146,3)
#  + 170 xim(1460,2) + 740 xim(1460,3) + 350 xim(1461,2) + 1340 xim(1461,3)
#  + 490 xim(1462,2) + 1760 xim(1462,3) + 520 xim(1463,2) + 1780 xim(1463,3)
#  + 430 xim(1464,2) + 1440 xim(1464,3) + 120 xim(1465,2) + 580 xim(1465,3)
#  + 300 xim(1466,2) + 1160 xim(1466,3) + 450 xim(1467,2) + 1720 xim(1467,3)
#  + 520 xim(1468,2) + 1780 xim(1468,3) + 630 xim(1469,2) + 1880 xim(1469,3)
#  + 450 xim(147,2) + 1720 xim(147,3) + 350 xim(1470,2) + 1340 xim(1470,3)
#  + 330 xim(1471,2) + 1300 xim(1471,3) + 130 xim(1472,2) + 640 xim(1472,3)
#  + 350 xim(1473,2) + 1340 xim(1473,3) + 140 xim(1474,2) + 660 xim(1474,3)
#  + 490 xim(1475,2) + 1760 xim(1475,3) + 140 xim(1476,2) + 660 xim(1476,3)
#  + 630 xim(1477,2) + 1880 xim(1477,3) + 420 xim(1478,2) + 1680 xim(1478,3)
#  + 350 xim(1479,2) + 1340 xim(1479,3) + 430 xim(148,2) + 1440 xim(148,3)
#  + 450 xim(1480,2) + 1720 xim(1480,3) + 140 xim(1481,2) + 660 xim(1481,3)
#  + 350 xim(1482,2) + 1340 xim(1482,3) + 450 xim(1483,2) + 1720 xim(1483,3)
#  + 450 xim(1484,2) + 1720 xim(1484,3) + 170 xim(1485,2) + 740 xim(1485,3)
#  + 170 xim(1486,2) + 740 xim(1486,3) + 450 xim(1487,2) + 1720 xim(1487,3)
#  + 140 xim(1488,2) + 660 xim(1488,3) + 630 xim(1489,2) + 1880 xim(1489,3)
#  + 350 xim(149,2) + 1340 xim(149,3) + 550 xim(1490,2) + 1860 xim(1490,3)
#  + 450 xim(1491,2) + 1720 xim(1491,3) + 490 xim(1492,2) + 1760 xim(1492,3)
#  + 520 xim(1493,2) + 1780 xim(1493,3) + 520 xim(1494,2) + 1780 xim(1494,3)
#  + 350 xim(1495,2) + 1340 xim(1495,3) + 520 xim(1496,2) + 1780 xim(1496,3)
#  + 490 xim(1497,2) + 1760 xim(1497,3) + 130 xim(1498,2) + 640 xim(1498,3)
#  + 140 xim(1499,2) + 660 xim(1499,3) + 130 xim(150,2) + 640 xim(150,3)
#  + 170 xim(1500,2) + 740 xim(1500,3) + 550 xim(1501,2) + 1860 xim(1501,3)
#  + 130 xim(1502,2) + 640 xim(1502,3) + 140 xim(1503,2) + 660 xim(1503,3)
#  + 140 xim(1504,2) + 660 xim(1504,3) + 550 xim(1505,2) + 1860 xim(1505,3)
#  + 170 xim(1506,2) + 740 xim(1506,3) + 350 xim(1507,2) + 1340 xim(1507,3)
#  + 630 xim(1508,2) + 1880 xim(1508,3) + 140 xim(1509,2) + 660 xim(1509,3)
#  + 130 xim(151,2) + 640 xim(151,3) + 630 xim(1510,2) + 1880 xim(1510,3)
#  + 630 xim(1511,2) + 1880 xim(1511,3) + 520 xim(1512,2) + 1780 xim(1512,3)
#  + 330 xim(1513,2) + 1300 xim(1513,3) + 140 xim(1514,2) + 660 xim(1514,3)
#  + 630 xim(1515,2) + 1880 xim(1515,3) + 170 xim(1516,2) + 740 xim(1516,3)
#  + 520 xim(1517,2) + 1780 xim(1517,3) + 430 xim(1518,2) + 1440 xim(1518,3)
#  + 140 xim(1519,2) + 660 xim(1519,3) + 130 xim(152,2) + 640 xim(152,3)
#  + 550 xim(1520,2) + 1860 xim(1520,3) + 630 xim(1521,2) + 1880 xim(1521,3)
#  + 140 xim(1522,2) + 660 xim(1522,3) + 140 xim(1523,2) + 660 xim(1523,3)
#  + 170 xim(1524,2) + 740 xim(1524,3) + 350 xim(1525,2) + 1340 xim(1525,3)
#  + 520 xim(1526,2) + 1780 xim(1526,3) + 330 xim(1527,2) + 1300 xim(1527,3)
#  + 170 xim(1528,2) + 740 xim(1528,3) + 170 xim(1529,2) + 740 xim(1529,3)
#  + 170 xim(153,2) + 740 xim(153,3) + 630 xim(1530,2) + 1880 xim(1530,3)
#  + 330 xim(1531,2) + 1300 xim(1531,3) + 420 xim(1532,2) + 1680 xim(1532,3)
#  + 300 xim(1533,2) + 1160 xim(1533,3) + 140 xim(1534,2) + 660 xim(1534,3)
#  + 430 xim(1535,2) + 1440 xim(1535,3) + 350 xim(1536,2) + 1340 xim(1536,3)
#  + 350 xim(1537,2) + 1340 xim(1537,3) + 520 xim(1538,2) + 1780 xim(1538,3)
#  + 430 xim(1539,2) + 1440 xim(1539,3) + 450 xim(154,2) + 1540 xim(154,3)
#  + 350 xim(1540,2) + 1340 xim(1540,3) + 430 xim(1541,2) + 1440 xim(1541,3)
#  + 430 xim(1542,2) + 1440 xim(1542,3) + 630 xim(1543,2) + 1880 xim(1543,3)
#  + 130 xim(1544,2) + 640 xim(1544,3) + 520 xim(1545,2) + 1780 xim(1545,3)
#  + 520 xim(1546,2) + 1780 xim(1546,3) + 420 xim(1547,2) + 1680 xim(1547,3)
#  + 130 xim(1548,2) + 640 xim(1548,3) + 430 xim(1549,2) + 1440 xim(1549,3)
#  + 140 xim(155,2) + 660 xim(155,3) + 170 xim(1550,2) + 740 xim(1550,3)
#  + 140 xim(1551,2) + 660 xim(1551,3) + 120 xim(1552,2) + 580 xim(1552,3)
#  + 430 xim(1553,2) + 1440 xim(1553,3) + 430 xim(1554,2) + 1440 xim(1554,3)
#  + 140 xim(1555,2) + 660 xim(1555,3) + 520 xim(1556,2) + 1780 xim(1556,3)
#  + 430 xim(1557,2) + 1440 xim(1557,3) + 430 xim(1558,2) + 1440 xim(1558,3)
#  + 550 xim(1559,2) + 1860 xim(1559,3) + 450 xim(156,2) + 1720 xim(156,3)
#  + 170 xim(1560,2) + 740 xim(1560,3) + 170 xim(1561,2) + 740 xim(1561,3)
#  + 300 xim(1562,2) + 1160 xim(1562,3) + 450 xim(1563,2) + 1720 xim(1563,3)
#  + 140 xim(1564,2) + 660 xim(1564,3) + 430 xim(1565,2) + 1440 xim(1565,3)
#  + 140 xim(1566,2) + 660 xim(1566,3) + 140 xim(1567,2) + 660 xim(1567,3)
#  + 120 xim(1568,2) + 580 xim(1568,3) + 130 xim(1569,2) + 640 xim(1569,3)
#  + 140 xim(157,2) + 660 xim(157,3) + 140 xim(1570,2) + 660 xim(1570,3)
#  + 630 xim(1571,2) + 1880 xim(1571,3) + 300 xim(1572,2) + 1160 xim(1572,3)
#  + 630 xim(1573,2) + 1880 xim(1573,3) + 140 xim(1574,2) + 660 xim(1574,3)
#  + 350 xim(1575,2) + 1340 xim(1575,3) + 140 xim(1576,2) + 660 xim(1576,3)
#  + 300 xim(1577,2) + 1160 xim(1577,3) + 520 xim(1578,2) + 1780 xim(1578,3)
#  + 550 xim(1579,2) + 1860 xim(1579,3) + 430 xim(158,2) + 1440 xim(158,3)
#  + 330 xim(1580,2) + 1300 xim(1580,3) + 350 xim(1581,2) + 1340 xim(1581,3)
#  + 450 xim(1582,2) + 1540 xim(1582,3) + 170 xim(1583,2) + 740 xim(1583,3)
#  + 140 xim(1584,2) + 660 xim(1584,3) + 630 xim(1585,2) + 1880 xim(1585,3)
#  + 130 xim(1586,2) + 640 xim(1586,3) + 140 xim(1587,2) + 660 xim(1587,3)
#  + 350 xim(1588,2) + 1340 xim(1588,3) + 170 xim(1589,2) + 740 xim(1589,3)
#  + 430 xim(159,2) + 1440 xim(159,3) + 520 xim(1590,2) + 1780 xim(1590,3)
#  + 520 xim(1591,2) + 1780 xim(1591,3) + 550 xim(1592,2) + 1860 xim(1592,3)
#  + 430 xim(1593,2) + 1440 xim(1593,3) + 520 xim(1594,2) + 1780 xim(1594,3)
#  + 520 xim(1595,2) + 1780 xim(1595,3) + 140 xim(1596,2) + 660 xim(1596,3)
#  + 170 xim(1597,2) + 740 xim(1597,3) + 140 xim(1598,2) + 660 xim(1598,3)
#  + 140 xim(1599,2) + 660 xim(1599,3) + 330 xim(160,2) + 1300 xim(160,3)
#  + 140 xim(1600,2) + 660 xim(1600,3) + 140 xim(1601,2) + 660 xim(1601,3)
#  + 170 xim(1602,2) + 740 xim(1602,3) + 130 xim(1603,2) + 640 xim(1603,3)
#  + 140 xim(1604,2) + 660 xim(1604,3) + 130 xim(1605,2) + 640 xim(1605,3)
#  + 430 xim(1606,2) + 1440 xim(1606,3) + 390 xim(1607,2) + 1480 xim(1607,3)
#  + 490 xim(1608,2) + 1760 xim(1608,3) + 140 xim(1609,2) + 660 xim(1609,3)
#  + 450 xim(161,2) + 1540 xim(161,3) + 520 xim(1610,2) + 1780 xim(1610,3)
#  + 350 xim(1611,2) + 1340 xim(1611,3) + 170 xim(1612,2) + 740 xim(1612,3)
#  + 350 xim(1613,2) + 1340 xim(1613,3) + 300 xim(1614,2) + 1160 xim(1614,3)
#  + 130 xim(1615,2) + 640 xim(1615,3) + 140 xim(1616,2) + 660 xim(1616,3)
#  + 300 xim(1617,2) + 1160 xim(1617,3) + 140 xim(1618,2) + 660 xim(1618,3)
#  + 630 xim(1619,2) + 1880 xim(1619,3) + 490 xim(162,2) + 1760 xim(162,3)
#  + 140 xim(1620,2) + 660 xim(1620,3) + 170 xim(1621,2) + 740 xim(1621,3)
#  + 130 xim(1622,2) + 640 xim(1622,3) + 130 xim(1623,2) + 640 xim(1623,3)
#  + 140 xim(1624,2) + 660 xim(1624,3) + 140 xim(1625,2) + 660 xim(1625,3)
#  + 330 xim(1626,2) + 1300 xim(1626,3) + 350 xim(1627,2) + 1340 xim(1627,3)
#  + 350 xim(1628,2) + 1340 xim(1628,3) + 550 xim(1629,2) + 1860 xim(1629,3)
#  + 170 xim(163,2) + 740 xim(163,3) + 330 xim(1630,2) + 1300 xim(1630,3)
#  + 420 xim(1631,2) + 1680 xim(1631,3) + 140 xim(1632,2) + 660 xim(1632,3)
#  + 520 xim(1633,2) + 1780 xim(1633,3) + 170 xim(1634,2) + 740 xim(1634,3)
#  + 170 xim(1635,2) + 740 xim(1635,3) + 430 xim(1636,2) + 1440 xim(1636,3)
#  + 140 xim(1637,2) + 660 xim(1637,3) + 170 xim(1638,2) + 740 xim(1638,3)
#  + 630 xim(1639,2) + 1880 xim(1639,3) + 130 xim(164,2) + 640 xim(164,3)
#  + 490 xim(1640,2) + 1760 xim(1640,3) + 630 xim(1641,2) + 1880 xim(1641,3)
#  + 350 xim(1642,2) + 1340 xim(1642,3) + 450 xim(1643,2) + 1540 xim(1643,3)
#  + 140 xim(1644,2) + 660 xim(1644,3) + 170 xim(1645,2) + 740 xim(1645,3)
#  + 350 xim(1646,2) + 1340 xim(1646,3) + 140 xim(1647,2) + 660 xim(1647,3)
#  + 130 xim(1648,2) + 640 xim(1648,3) + 170 xim(1649,2) + 740 xim(1649,3)
#  + 330 xim(165,2) + 1300 xim(165,3) + 550 xim(1650,2) + 1860 xim(1650,3)
#  + 490 xim(1651,2) + 1760 xim(1651,3) + 120 xim(1652,2) + 580 xim(1652,3)
#  + 350 xim(1653,2) + 1340 xim(1653,3) + 630 xim(1654,2) + 1880 xim(1654,3)
#  + 140 xim(1655,2) + 660 xim(1655,3) + 350 xim(1656,2) + 1340 xim(1656,3)
#  + 430 xim(1657,2) + 1440 xim(1657,3) + 350 xim(1658,2) + 1340 xim(1658,3)
#  + 140 xim(1659,2) + 660 xim(1659,3) + 140 xim(166,2) + 660 xim(166,3)
#  + 120 xim(1660,2) + 580 xim(1660,3) + 490 xim(1661,2) + 1760 xim(1661,3)
#  + 350 xim(1662,2) + 1340 xim(1662,3) + 350 xim(1663,2) + 1340 xim(1663,3)
#  + 350 xim(1664,2) + 1340 xim(1664,3) + 330 xim(1665,2) + 1300 xim(1665,3)
#  + 630 xim(1666,2) + 1880 xim(1666,3) + 430 xim(1667,2) + 1440 xim(1667,3)
#  + 170 xim(1668,2) + 740 xim(1668,3) + 430 xim(1669,2) + 1440 xim(1669,3)
#  + 520 xim(167,2) + 1780 xim(167,3) + 120 xim(1670,2) + 580 xim(1670,3)
#  + 330 xim(1671,2) + 1300 xim(1671,3) + 350 xim(1672,2) + 1340 xim(1672,3)
#  + 140 xim(1673,2) + 660 xim(1673,3) + 430 xim(1674,2) + 1440 xim(1674,3)
#  + 140 xim(1675,2) + 660 xim(1675,3) + 350 xim(1676,2) + 1340 xim(1676,3)
#  + 140 xim(1677,2) + 660 xim(1677,3) + 430 xim(1678,2) + 1440 xim(1678,3)
#  + 330 xim(1679,2) + 1300 xim(1679,3) + 140 xim(168,2) + 660 xim(168,3)
#  + 330 xim(1680,2) + 1300 xim(1680,3) + 430 xim(1681,2) + 1440 xim(1681,3)
#  + 140 xim(1682,2) + 660 xim(1682,3) + 130 xim(1683,2) + 640 xim(1683,3)
#  + 120 xim(1684,2) + 580 xim(1684,3) + 430 xim(1685,2) + 1440 xim(1685,3)
#  + 350 xim(1686,2) + 1340 xim(1686,3) + 520 xim(1687,2) + 1780 xim(1687,3)
#  + 140 xim(1688,2) + 660 xim(1688,3) + 350 xim(1689,2) + 1340 xim(1689,3)
#  + 170 xim(169,2) + 740 xim(169,3) + 140 xim(1690,2) + 660 xim(1690,3)
#  + 520 xim(1691,2) + 1780 xim(1691,3) + 430 xim(1692,2) + 1440 xim(1692,3)
#  + 490 xim(1693,2) + 1760 xim(1693,3) + 330 xim(1694,2) + 1300 xim(1694,3)
#  + 170 xim(1695,2) + 740 xim(1695,3) + 140 xim(1696,2) + 660 xim(1696,3)
#  + 120 xim(1697,2) + 580 xim(1697,3) + 170 xim(1698,2) + 740 xim(1698,3)
#  + 300 xim(1699,2) + 1160 xim(1699,3) + 130 xim(170,2) + 640 xim(170,3)
#  + 130 xim(1700,2) + 640 xim(1700,3) + 300 xim(1701,2) + 1160 xim(1701,3)
#  + 140 xim(1702,2) + 660 xim(1702,3) + 390 xim(1703,2) + 1480 xim(1703,3)
#  + 430 xim(1704,2) + 1440 xim(1704,3) + 490 xim(1705,2) + 1760 xim(1705,3)
#  + 430 xim(1706,2) + 1440 xim(1706,3) + 350 xim(1707,2) + 1340 xim(1707,3)
#  + 430 xim(1708,2) + 1440 xim(1708,3) + 300 xim(1709,2) + 1160 xim(1709,3)
#  + 120 xim(171,2) + 580 xim(171,3) + 140 xim(1710,2) + 660 xim(1710,3)
#  + 520 xim(1711,2) + 1780 xim(1711,3) + 130 xim(1712,2) + 640 xim(1712,3)
#  + 170 xim(1713,2) + 740 xim(1713,3) + 140 xim(1714,2) + 660 xim(1714,3)
#  + 170 xim(1715,2) + 740 xim(1715,3) + 170 xim(1716,2) + 740 xim(1716,3)
#  + 630 xim(1717,2) + 1880 xim(1717,3) + 130 xim(1718,2) + 640 xim(1718,3)
#  + 430 xim(1719,2) + 1440 xim(1719,3) + 130 xim(172,2) + 640 xim(172,3)
#  + 450 xim(1720,2) + 1720 xim(1720,3) + 490 xim(1721,2) + 1760 xim(1721,3)
#  + 140 xim(1722,2) + 660 xim(1722,3) + 140 xim(1723,2) + 660 xim(1723,3)
#  + 140 xim(1724,2) + 660 xim(1724,3) + 130 xim(1725,2) + 640 xim(1725,3)
#  + 330 xim(1726,2) + 1300 xim(1726,3) + 490 xim(1727,2) + 1760 xim(1727,3)
#  + 520 xim(1728,2) + 1780 xim(1728,3) + 520 xim(1729,2) + 1780 xim(1729,3)
#  + 170 xim(173,2) + 740 xim(173,3) + 430 xim(1730,2) + 1440 xim(1730,3)
#  + 450 xim(1731,2) + 1720 xim(1731,3) + 520 xim(1732,2) + 1780 xim(1732,3)
#  + 170 xim(1733,2) + 740 xim(1733,3) + 330 xim(1734,2) + 1300 xim(1734,3)
#  + 550 xim(1735,2) + 1860 xim(1735,3) + 170 xim(1736,2) + 740 xim(1736,3)
#  + 350 xim(1737,2) + 1340 xim(1737,3) + 330 xim(1738,2) + 1300 xim(1738,3)
#  + 300 xim(1739,2) + 1160 xim(1739,3) + 170 xim(174,2) + 740 xim(174,3)
#  + 520 xim(1740,2) + 1780 xim(1740,3) + 390 xim(1741,2) + 1480 xim(1741,3)
#  + 430 xim(1742,2) + 1440 xim(1742,3) + 300 xim(1743,2) + 1160 xim(1743,3)
#  + 430 xim(1744,2) + 1440 xim(1744,3) + 140 xim(1745,2) + 660 xim(1745,3)
#  + 630 xim(1746,2) + 1880 xim(1746,3) + 170 xim(1747,2) + 740 xim(1747,3)
#  + 550 xim(1748,2) + 1860 xim(1748,3) + 300 xim(1749,2) + 1160 xim(1749,3)
#  + 170 xim(175,2) + 740 xim(175,3) + 350 xim(1750,2) + 1340 xim(1750,3)
#  + 350 xim(1751,2) + 1340 xim(1751,3) + 140 xim(1752,2) + 660 xim(1752,3)
#  + 140 xim(1753,2) + 660 xim(1753,3) + 170 xim(1754,2) + 740 xim(1754,3)
#  + 130 xim(1755,2) + 640 xim(1755,3) + 170 xim(1756,2) + 740 xim(1756,3)
#  + 520 xim(1757,2) + 1780 xim(1757,3) + 170 xim(1758,2) + 740 xim(1758,3)
#  + 420 xim(1759,2) + 1680 xim(1759,3) + 140 xim(176,2) + 660 xim(176,3)
#  + 130 xim(1760,2) + 640 xim(1760,3) + 350 xim(1761,2) + 1340 xim(1761,3)
#  + 350 xim(1762,2) + 1340 xim(1762,3) + 140 xim(1763,2) + 660 xim(1763,3)
#  + 350 xim(1764,2) + 1340 xim(1764,3) + 140 xim(1765,2) + 660 xim(1765,3)
#  + 350 xim(1766,2) + 1340 xim(1766,3) + 170 xim(1767,2) + 740 xim(1767,3)
#  + 520 xim(1768,2) + 1780 xim(1768,3) + 130 xim(1769,2) + 640 xim(1769,3)
#  + 490 xim(177,2) + 1760 xim(177,3) + 300 xim(1770,2) + 1160 xim(1770,3)
#  + 300 xim(1771,2) + 1160 xim(1771,3) + 140 xim(1772,2) + 660 xim(1772,3)
#  + 330 xim(1773,2) + 1300 xim(1773,3) + 120 xim(1774,2) + 580 xim(1774,3)
#  + 120 xim(1775,2) + 580 xim(1775,3) + 140 xim(1776,2) + 660 xim(1776,3)
#  + 300 xim(1777,2) + 1160 xim(1777,3) + 140 xim(1778,2) + 660 xim(1778,3)
#  + 330 xim(1779,2) + 1300 xim(1779,3) + 170 xim(178,2) + 740 xim(178,3)
#  + 130 xim(1780,2) + 640 xim(1780,3) + 170 xim(1781,2) + 740 xim(1781,3)
#  + 130 xim(1782,2) + 640 xim(1782,3) + 350 xim(1783,2) + 1340 xim(1783,3)
#  + 130 xim(1784,2) + 640 xim(1784,3) + 350 xim(1785,2) + 1340 xim(1785,3)
#  + 350 xim(1786,2) + 1340 xim(1786,3) + 520 xim(1787,2) + 1780 xim(1787,3)
#  + 170 xim(1788,2) + 740 xim(1788,3) + 430 xim(1789,2) + 1440 xim(1789,3)
#  + 430 xim(179,2) + 1440 xim(179,3) + 140 xim(1790,2) + 660 xim(1790,3)
#  + 140 xim(1791,2) + 660 xim(1791,3) + 140 xim(1792,2) + 660 xim(1792,3)
#  + 450 xim(1793,2) + 1720 xim(1793,3) + 170 xim(1794,2) + 740 xim(1794,3)
#  + 300 xim(1795,2) + 1160 xim(1795,3) + 140 xim(1796,2) + 660 xim(1796,3)
#  + 170 xim(1797,2) + 740 xim(1797,3) + 350 xim(1798,2) + 1340 xim(1798,3)
#  + 170 xim(1799,2) + 740 xim(1799,3) + 140 xim(180,2) + 660 xim(180,3)
#  + 140 xim(1800,2) + 660 xim(1800,3) + 520 xim(1801,2) + 1780 xim(1801,3)
#  + 430 xim(1802,2) + 1440 xim(1802,3) + 630 xim(1803,2) + 1880 xim(1803,3)
#  + 330 xim(1804,2) + 1300 xim(1804,3) + 140 xim(1805,2) + 660 xim(1805,3)
#  + 170 xim(1806,2) + 740 xim(1806,3) + 170 xim(1807,2) + 740 xim(1807,3)
#  + 170 xim(1808,2) + 740 xim(1808,3) + 170 xim(1809,2) + 740 xim(1809,3)
#  + 140 xim(181,2) + 660 xim(181,3) + 520 xim(1810,2) + 1780 xim(1810,3)
#  + 350 xim(1811,2) + 1340 xim(1811,3) + 140 xim(1812,2) + 660 xim(1812,3)
#  + 350 xim(1813,2) + 1340 xim(1813,3) + 430 xim(1814,2) + 1440 xim(1814,3)
#  + 390 xim(1815,2) + 1480 xim(1815,3) + 350 xim(1816,2) + 1340 xim(1816,3)
#  + 170 xim(1817,2) + 740 xim(1817,3) + 450 xim(1818,2) + 1540 xim(1818,3)
#  + 170 xim(1819,2) + 740 xim(1819,3) + 330 xim(182,2) + 1300 xim(182,3)
#  + 140 xim(1820,2) + 660 xim(1820,3) + 430 xim(1821,2) + 1440 xim(1821,3)
#  + 450 xim(1822,2) + 1720 xim(1822,3) + 330 xim(1823,2) + 1300 xim(1823,3)
#  + 390 xim(1824,2) + 1480 xim(1824,3) + 140 xim(1825,2) + 660 xim(1825,3)
#  + 520 xim(1826,2) + 1780 xim(1826,3) + 140 xim(1827,2) + 660 xim(1827,3)
#  + 450 xim(1828,2) + 1720 xim(1828,3) + 520 xim(1829,2) + 1780 xim(1829,3)
#  + 350 xim(183,2) + 1340 xim(183,3) + 430 xim(1830,2) + 1440 xim(1830,3)
#  + 430 xim(1831,2) + 1440 xim(1831,3) + 140 xim(1832,2) + 660 xim(1832,3)
#  + 170 xim(1833,2) + 740 xim(1833,3) + 140 xim(1834,2) + 660 xim(1834,3)
#  + 430 xim(1835,2) + 1440 xim(1835,3) + 450 xim(1836,2) + 1720 xim(1836,3)
#  + 630 xim(1837,2) + 1880 xim(1837,3) + 350 xim(1838,2) + 1340 xim(1838,3)
#  + 450 xim(1839,2) + 1720 xim(1839,3) + 140 xim(184,2) + 660 xim(184,3)
#  + 330 xim(1840,2) + 1300 xim(1840,3) + 300 xim(1841,2) + 1160 xim(1841,3)
#  + 350 xim(1842,2) + 1340 xim(1842,3) + 330 xim(1843,2) + 1300 xim(1843,3)
#  + 450 xim(1844,2) + 1720 xim(1844,3) + 520 xim(1845,2) + 1780 xim(1845,3)
#  + 520 xim(1846,2) + 1780 xim(1846,3) + 450 xim(1847,2) + 1720 xim(1847,3)
#  + 520 xim(1848,2) + 1780 xim(1848,3) + 140 xim(1849,2) + 660 xim(1849,3)
#  + 170 xim(185,2) + 740 xim(185,3) + 130 xim(1850,2) + 640 xim(1850,3)
#  + 130 xim(1851,2) + 640 xim(1851,3) + 140 xim(1852,2) + 660 xim(1852,3)
#  + 350 xim(1853,2) + 1340 xim(1853,3) + 490 xim(1854,2) + 1760 xim(1854,3)
#  + 140 xim(1855,2) + 660 xim(1855,3) + 130 xim(1856,2) + 640 xim(1856,3)
#  + 170 xim(1857,2) + 740 xim(1857,3) + 130 xim(1858,2) + 640 xim(1858,3)
#  + 170 xim(1859,2) + 740 xim(1859,3) + 170 xim(186,2) + 740 xim(186,3)
#  + 330 xim(1860,2) + 1300 xim(1860,3) + 140 xim(1861,2) + 660 xim(1861,3)
#  + 170 xim(1862,2) + 740 xim(1862,3) + 350 xim(1863,2) + 1340 xim(1863,3)
#  + 450 xim(1864,2) + 1540 xim(1864,3) + 630 xim(1865,2) + 1880 xim(1865,3)
#  + 330 xim(1866,2) + 1300 xim(1866,3) + 350 xim(1867,2) + 1340 xim(1867,3)
#  + 630 xim(1868,2) + 1880 xim(1868,3) + 170 xim(1869,2) + 740 xim(1869,3)
#  + 520 xim(187,2) + 1780 xim(187,3) + 490 xim(1870,2) + 1760 xim(1870,3)
#  + 120 xim(1871,2) + 580 xim(1871,3) + 450 xim(1872,2) + 1540 xim(1872,3)
#  + 350 xim(1873,2) + 1340 xim(1873,3) + 140 xim(1874,2) + 660 xim(1874,3)
#  + 170 xim(1875,2) + 740 xim(1875,3) + 170 xim(1876,2) + 740 xim(1876,3)
#  + 170 xim(1877,2) + 740 xim(1877,3) + 430 xim(1878,2) + 1440 xim(1878,3)
#  + 490 xim(1879,2) + 1760 xim(1879,3) + 140 xim(188,2) + 660 xim(188,3)
#  + 170 xim(1880,2) + 740 xim(1880,3) + 170 xim(1881,2) + 740 xim(1881,3)
#  + 140 xim(1882,2) + 660 xim(1882,3) + 430 xim(1883,2) + 1440 xim(1883,3)
#  + 170 xim(1884,2) + 740 xim(1884,3) + 170 xim(1885,2) + 740 xim(1885,3)
#  + 120 xim(1886,2) + 580 xim(1886,3) + 170 xim(1887,2) + 740 xim(1887,3)
#  + 630 xim(1888,2) + 1880 xim(1888,3) + 350 xim(1889,2) + 1340 xim(1889,3)
#  + 170 xim(189,2) + 740 xim(189,3) + 130 xim(1890,2) + 640 xim(1890,3)
#  + 550 xim(1891,2) + 1860 xim(1891,3) + 550 xim(1892,2) + 1860 xim(1892,3)
#  + 170 xim(1893,2) + 740 xim(1893,3) + 430 xim(1894,2) + 1440 xim(1894,3)
#  + 450 xim(1895,2) + 1720 xim(1895,3) + 330 xim(1896,2) + 1300 xim(1896,3)
#  + 430 xim(1897,2) + 1440 xim(1897,3) + 300 xim(1898,2) + 1160 xim(1898,3)
#  + 630 xim(1899,2) + 1880 xim(1899,3) + 170 xim(190,2) + 740 xim(190,3)
#  + 170 xim(1900,2) + 740 xim(1900,3) + 450 xim(1901,2) + 1540 xim(1901,3)
#  + 630 xim(1902,2) + 1880 xim(1902,3) + 630 xim(1903,2) + 1880 xim(1903,3)
#  + 170 xim(1904,2) + 740 xim(1904,3) + 350 xim(1905,2) + 1340 xim(1905,3)
#  + 450 xim(1906,2) + 1540 xim(1906,3) + 520 xim(1907,2) + 1780 xim(1907,3)
#  + 520 xim(1908,2) + 1780 xim(1908,3) + 170 xim(1909,2) + 740 xim(1909,3)
#  + 330 xim(191,2) + 1300 xim(191,3) + 520 xim(1910,2) + 1780 xim(1910,3)
#  + 520 xim(1911,2) + 1780 xim(1911,3) + 630 xim(1912,2) + 1880 xim(1912,3)
#  + 140 xim(1913,2) + 660 xim(1913,3) + 350 xim(1914,2) + 1340 xim(1914,3)
#  + 330 xim(1915,2) + 1300 xim(1915,3) + 630 xim(1916,2) + 1880 xim(1916,3)
#  + 430 xim(1917,2) + 1440 xim(1917,3) + 170 xim(1918,2) + 740 xim(1918,3)
#  + 430 xim(1919,2) + 1440 xim(1919,3) + 520 xim(192,2) + 1780 xim(192,3)
#  + 490 xim(1920,2) + 1760 xim(1920,3) + 330 xim(1921,2) + 1300 xim(1921,3)
#  + 170 xim(1922,2) + 740 xim(1922,3) + 350 xim(1923,2) + 1340 xim(1923,3)
#  + 130 xim(1924,2) + 640 xim(1924,3) + 520 xim(1925,2) + 1780 xim(1925,3)
#  + 140 xim(1926,2) + 660 xim(1926,3) + 170 xim(1927,2) + 740 xim(1927,3)
#  + 350 xim(1928,2) + 1340 xim(1928,3) + 550 xim(1929,2) + 1860 xim(1929,3)
#  + 630 xim(193,2) + 1880 xim(193,3) + 130 xim(1930,2) + 640 xim(1930,3)
#  + 430 xim(1931,2) + 1440 xim(1931,3) + 550 xim(1932,2) + 1860 xim(1932,3)
#  + 550 xim(1933,2) + 1860 xim(1933,3) + 330 xim(1934,2) + 1300 xim(1934,3)
#  + 140 xim(1935,2) + 660 xim(1935,3) + 330 xim(1936,2) + 1300 xim(1936,3)
#  + 170 xim(1937,2) + 740 xim(1937,3) + 430 xim(1938,2) + 1440 xim(1938,3)
#  + 490 xim(1939,2) + 1760 xim(1939,3) + 130 xim(194,2) + 640 xim(194,3)
#  + 350 xim(1940,2) + 1340 xim(1940,3) + 350 xim(1941,2) + 1340 xim(1941,3)
#  + 170 xim(1942,2) + 740 xim(1942,3) + 450 xim(1943,2) + 1720 xim(1943,3)
#  + 140 xim(1944,2) + 660 xim(1944,3) + 130 xim(1945,2) + 640 xim(1945,3)
#  + 520 xim(1946,2) + 1780 xim(1946,3) + 130 xim(1947,2) + 640 xim(1947,3)
#  + 390 xim(1948,2) + 1480 xim(1948,3) + 450 xim(1949,2) + 1720 xim(1949,3)
#  + 350 xim(195,2) + 1340 xim(195,3) + 140 xim(1950,2) + 660 xim(1950,3)
#  + 330 xim(1951,2) + 1300 xim(1951,3) + 140 xim(1952,2) + 660 xim(1952,3)
#  + 300 xim(1953,2) + 1160 xim(1953,3) + 330 xim(1954,2) + 1300 xim(1954,3)
#  + 350 xim(1955,2) + 1340 xim(1955,3) + 450 xim(1956,2) + 1720 xim(1956,3)
#  + 130 xim(1957,2) + 640 xim(1957,3) + 170 xim(1958,2) + 740 xim(1958,3)
#  + 170 xim(1959,2) + 740 xim(1959,3) + 350 xim(196,2) + 1340 xim(196,3)
#  + 630 xim(1960,2) + 1880 xim(1960,3) + 490 xim(1961,2) + 1760 xim(1961,3)
#  + 430 xim(1962,2) + 1440 xim(1962,3) + 130 xim(1963,2) + 640 xim(1963,3)
#  + 450 xim(1964,2) + 1720 xim(1964,3) + 330 xim(1965,2) + 1300 xim(1965,3)
#  + 520 xim(1966,2) + 1780 xim(1966,3) + 130 xim(1967,2) + 640 xim(1967,3)
#  + 520 xim(1968,2) + 1780 xim(1968,3) + 350 xim(1969,2) + 1340 xim(1969,3)
#  + 120 xim(197,2) + 580 xim(197,3) + 450 xim(1970,2) + 1720 xim(1970,3)
#  + 170 xim(1971,2) + 740 xim(1971,3) + 430 xim(1972,2) + 1440 xim(1972,3)
#  + 130 xim(1973,2) + 640 xim(1973,3) + 330 xim(1974,2) + 1300 xim(1974,3)
#  + 130 xim(1975,2) + 640 xim(1975,3) + 450 xim(1976,2) + 1540 xim(1976,3)
#  + 430 xim(1977,2) + 1440 xim(1977,3) + 130 xim(1978,2) + 640 xim(1978,3)
#  + 430 xim(1979,2) + 1440 xim(1979,3) + 130 xim(198,2) + 640 xim(198,3)
#  + 430 xim(1980,2) + 1440 xim(1980,3) + 520 xim(1981,2) + 1780 xim(1981,3)
#  + 490 xim(1982,2) + 1760 xim(1982,3) + 630 xim(1983,2) + 1880 xim(1983,3)
#  + 450 xim(1984,2) + 1540 xim(1984,3) + 140 xim(1985,2) + 660 xim(1985,3)
#  + 350 xim(1986,2) + 1340 xim(1986,3) + 350 xim(1987,2) + 1340 xim(1987,3)
#  + 140 xim(1988,2) + 660 xim(1988,3) + 350 xim(1989,2) + 1340 xim(1989,3)
#  + 550 xim(199,2) + 1860 xim(199,3) + 520 xim(1990,2) + 1780 xim(1990,3)
#  + 170 xim(1991,2) + 740 xim(1991,3) + 140 xim(1992,2) + 660 xim(1992,3)
#  + 630 xim(1993,2) + 1880 xim(1993,3) + 350 xim(1994,2) + 1340 xim(1994,3)
#  + 140 xim(1995,2) + 660 xim(1995,3) + 350 xim(1996,2) + 1340 xim(1996,3)
#  + 130 xim(1997,2) + 640 xim(1997,3) + 490 xim(1998,2) + 1760 xim(1998,3)
#  + 630 xim(1999,2) + 1880 xim(1999,3) + 550 xim(200,2) + 1860 xim(200,3)
#  + 420 xim(2000,2) + 1680 xim(2000,3) + 350 xim(2001,2) + 1340 xim(2001,3)
#  + 430 xim(2002,2) + 1440 xim(2002,3) + 490 xim(2003,2) + 1760 xim(2003,3)
#  + 520 xim(2004,2) + 1780 xim(2004,3) + 170 xim(2005,2) + 740 xim(2005,3)
#  + 630 xim(2006,2) + 1880 xim(2006,3) + 140 xim(2007,2) + 660 xim(2007,3)
#  + 140 xim(2008,2) + 660 xim(2008,3) + 300 xim(2009,2) + 1160 xim(2009,3)
#  + 350 xim(201,2) + 1340 xim(201,3) + 330 xim(2010,2) + 1300 xim(2010,3)
#  + 430 xim(2011,2) + 1440 xim(2011,3) + 130 xim(2012,2) + 640 xim(2012,3)
#  + 520 xim(2013,2) + 1780 xim(2013,3) + 330 xim(2014,2) + 1300 xim(2014,3)
#  + 130 xim(2015,2) + 640 xim(2015,3) + 130 xim(2016,2) + 640 xim(2016,3)
#  + 120 xim(2017,2) + 580 xim(2017,3) + 170 xim(2018,2) + 740 xim(2018,3)
#  + 120 xim(2019,2) + 580 xim(2019,3) + 170 xim(202,2) + 740 xim(202,3)
#  + 140 xim(2020,2) + 660 xim(2020,3) + 550 xim(2021,2) + 1860 xim(2021,3)
#  + 120 xim(2022,2) + 580 xim(2022,3) + 140 xim(2023,2) + 660 xim(2023,3)
#  + 170 xim(2024,2) + 740 xim(2024,3) + 140 xim(2025,2) + 660 xim(2025,3)
#  + 630 xim(2026,2) + 1880 xim(2026,3) + 170 xim(2027,2) + 740 xim(2027,3)
#  + 350 xim(2028,2) + 1340 xim(2028,3) + 120 xim(2029,2) + 580 xim(2029,3)
#  + 520 xim(203,2) + 1780 xim(203,3) + 170 xim(2030,2) + 740 xim(2030,3)
#  + 170 xim(2031,2) + 740 xim(2031,3) + 490 xim(2032,2) + 1760 xim(2032,3)
#  + 120 xim(2033,2) + 580 xim(2033,3) + 390 xim(2034,2) + 1480 xim(2034,3)
#  + 330 xim(2035,2) + 1300 xim(2035,3) + 630 xim(2036,2) + 1880 xim(2036,3)
#  + 130 xim(2037,2) + 640 xim(2037,3) + 350 xim(2038,2) + 1340 xim(2038,3)
#  + 450 xim(2039,2) + 1720 xim(2039,3) + 120 xim(204,2) + 580 xim(204,3)
#  + 330 xim(2040,2) + 1300 xim(2040,3) + 120 xim(2041,2) + 580 xim(2041,3)
#  + 350 xim(2042,2) + 1340 xim(2042,3) + 140 xim(2043,2) + 660 xim(2043,3)
#  + 430 xim(2044,2) + 1440 xim(2044,3) + 170 xim(2045,2) + 740 xim(2045,3)
#  + 350 xim(2046,2) + 1340 xim(2046,3) + 350 xim(2047,2) + 1340 xim(2047,3)
#  + 450 xim(2048,2) + 1720 xim(2048,3) + 170 xim(2049,2) + 740 xim(2049,3)
#  + 350 xim(205,2) + 1340 xim(205,3) + 450 xim(2050,2) + 1720 xim(2050,3)
#  + 390 xim(2051,2) + 1480 xim(2051,3) + 520 xim(2052,2) + 1780 xim(2052,3)
#  + 550 xim(2053,2) + 1860 xim(2053,3) + 330 xim(2054,2) + 1300 xim(2054,3)
#  + 350 xim(2055,2) + 1340 xim(2055,3) + 350 xim(2056,2) + 1340 xim(2056,3)
#  + 170 xim(2057,2) + 740 xim(2057,3) + 130 xim(2058,2) + 640 xim(2058,3)
#  + 550 xim(2059,2) + 1860 xim(2059,3) + 130 xim(206,2) + 640 xim(206,3)
#  + 170 xim(2060,2) + 740 xim(2060,3) + 430 xim(2061,2) + 1440 xim(2061,3)
#  + 140 xim(2062,2) + 660 xim(2062,3) + 520 xim(2063,2) + 1780 xim(2063,3)
#  + 330 xim(2064,2) + 1300 xim(2064,3) + 430 xim(2065,2) + 1440 xim(2065,3)
#  + 330 xim(2066,2) + 1300 xim(2066,3) + 140 xim(2067,2) + 660 xim(2067,3)
#  + 430 xim(2068,2) + 1440 xim(2068,3) + 140 xim(2069,2) + 660 xim(2069,3)
#  + 140 xim(207,2) + 660 xim(207,3) + 430 xim(2070,2) + 1440 xim(2070,3)
#  + 520 xim(2071,2) + 1780 xim(2071,3) + 140 xim(2072,2) + 660 xim(2072,3)
#  + 430 xim(2073,2) + 1440 xim(2073,3) + 140 xim(2074,2) + 660 xim(2074,3)
#  + 120 xim(2075,2) + 580 xim(2075,3) + 140 xim(2076,2) + 660 xim(2076,3)
#  + 300 xim(2077,2) + 1160 xim(2077,3) + 140 xim(2078,2) + 660 xim(2078,3)
#  + 350 xim(2079,2) + 1340 xim(2079,3) + 330 xim(208,2) + 1300 xim(208,3)
#  + 130 xim(2080,2) + 640 xim(2080,3) + 140 xim(2081,2) + 660 xim(2081,3)
#  + 630 xim(2082,2) + 1880 xim(2082,3) + 130 xim(2083,2) + 640 xim(2083,3)
#  + 140 xim(2084,2) + 660 xim(2084,3) + 450 xim(2085,2) + 1720 xim(2085,3)
#  + 330 xim(2086,2) + 1300 xim(2086,3) + 140 xim(2087,2) + 660 xim(2087,3)
#  + 430 xim(2088,2) + 1440 xim(2088,3) + 140 xim(2089,2) + 660 xim(2089,3)
#  + 490 xim(209,2) + 1760 xim(209,3) + 450 xim(2090,2) + 1720 xim(2090,3)
#  + 450 xim(2091,2) + 1540 xim(2091,3) + 430 xim(2092,2) + 1440 xim(2092,3)
#  + 630 xim(2093,2) + 1880 xim(2093,3) + 330 xim(2094,2) + 1300 xim(2094,3)
# ...
# 0 <= xim(724,3) <= 1 Integer
# 0 <= xim(725,2) <= 1 Integer
# 0 <= xim(725,3) <= 1 Integer
# 0 <= xim(726,2) <= 1 Integer
# 0 <= xim(726,3) <= 1 Integer
# 0 <= xim(727,2) <= 1 Integer
# 0 <= xim(727,3) <= 1 Integer
# 0 <= xim(728,2) <= 1 Integer
# 0 <= xim(728,3) <= 1 Integer
# 0 <= xim(729,2) <= 1 Integer
# 0 <= xim(729,3) <= 1 Integer
# 0 <= xim(730,2) <= 1 Integer
# 0 <= xim(730,3) <= 1 Integer
# 0 <= xim(731,2) <= 1 Integer
# 0 <= xim(731,3) <= 1 Integer
# 0 <= xim(732,2) <= 1 Integer
# 0 <= xim(732,3) <= 1 Integer
# 0 <= xim(733,2) <= 1 Integer
# 0 <= xim(733,3) <= 1 Integer
# 0 <= xim(734,2) <= 1 Integer
# 0 <= xim(734,3) <= 1 Integer
# 0 <= xim(735,2) <= 1 Integer
# 0 <= xim(735,3) <= 1 Integer
# 0 <= xim(736,2) <= 1 Integer
# 0 <= xim(736,3) <= 1 Integer
# 0 <= xim(737,2) <= 1 Integer
# 0 <= xim(737,3) <= 1 Integer
# 0 <= xim(738,2) <= 1 Integer
# 0 <= xim(738,3) <= 1 Integer
# 0 <= xim(739,2) <= 1 Integer
# 0 <= xim(739,3) <= 1 Integer
# 0 <= xim(740,2) <= 1 Integer
# 0 <= xim(740,3) <= 1 Integer
# 0 <= xim(741,2) <= 1 Integer
# 0 <= xim(741,3) <= 1 Integer
# 0 <= xim(742,2) <= 1 Integer
# 0 <= xim(742,3) <= 1 Integer
# 0 <= xim(743,2) <= 1 Integer
# 0 <= xim(743,3) <= 1 Integer
# 0 <= xim(744,2) <= 1 Integer
# 0 <= xim(744,3) <= 1 Integer
# 0 <= xim(745,2) <= 1 Integer
# 0 <= xim(745,3) <= 1 Integer
# 0 <= xim(746,2) <= 1 Integer
# 0 <= xim(746,3) <= 1 Integer
# 0 <= xim(747,2) <= 1 Integer
# 0 <= xim(747,3) <= 1 Integer
# 0 <= xim(748,2) <= 1 Integer
# 0 <= xim(748,3) <= 1 Integer
# 0 <= xim(749,2) <= 1 Integer
# 0 <= xim(749,3) <= 1 Integer
# 0 <= xim(750,2) <= 1 Integer
# 0 <= xim(750,3) <= 1 Integer
# 0 <= xim(751,2) <= 1 Integer
# 0 <= xim(751,3) <= 1 Integer
# 0 <= xim(752,2) <= 1 Integer
# 0 <= xim(752,3) <= 1 Integer
# 0 <= xim(753,2) <= 1 Integer
# 0 <= xim(753,3) <= 1 Integer
# 0 <= xim(754,2) <= 1 Integer
# 0 <= xim(754,3) <= 1 Integer
# 0 <= xim(755,2) <= 1 Integer
# 0 <= xim(755,3) <= 1 Integer
# 0 <= xim(756,2) <= 1 Integer
# 0 <= xim(756,3) <= 1 Integer
# 0 <= xim(757,2) <= 1 Integer
# 0 <= xim(757,3) <= 1 Integer
# 0 <= xim(758,2) <= 1 Integer
# 0 <= xim(758,3) <= 1 Integer
# 0 <= xim(759,2) <= 1 Integer
# 0 <= xim(759,3) <= 1 Integer
# 0 <= xim(760,2) <= 1 Integer
# 0 <= xim(760,3) <= 1 Integer
# 0 <= xim(761,2) <= 1 Integer
# 0 <= xim(761,3) <= 1 Integer
# 0 <= xim(762,2) <= 1 Integer
# 0 <= xim(762,3) <= 1 Integer
# 0 <= xim(763,2) <= 1 Integer
# 0 <= xim(763,3) <= 1 Integer
# 0 <= xim(764,2) <= 1 Integer
# 0 <= xim(764,3) <= 1 Integer
# 0 <= xim(765,2) <= 1 Integer
# 0 <= xim(765,3) <= 1 Integer
# 0 <= xim(766,2) <= 1 Integer
# 0 <= xim(766,3) <= 1 Integer
# 0 <= xim(767,2) <= 1 Integer
# 0 <= xim(767,3) <= 1 Integer
# 0 <= xim(768,2) <= 1 Integer
# 0 <= xim(768,3) <= 1 Integer
# 0 <= xim(769,2) <= 1 Integer
# 0 <= xim(769,3) <= 1 Integer
# 0 <= xim(770,2) <= 1 Integer
# 0 <= xim(770,3) <= 1 Integer
# 0 <= xim(771,2) <= 1 Integer
# 0 <= xim(771,3) <= 1 Integer
# 0 <= xim(772,2) <= 1 Integer
# 0 <= xim(772,3) <= 1 Integer
# 0 <= xim(773,2) <= 1 Integer
# 0 <= xim(773,3) <= 1 Integer
# 0 <= xim(774,2) <= 1 Integer
# 0 <= xim(774,3) <= 1 Integer
# 0 <= xim(775,2) <= 1 Integer
# 0 <= xim(775,3) <= 1 Integer
# 0 <= xim(776,2) <= 1 Integer
# 0 <= xim(776,3) <= 1 Integer
# 0 <= xim(777,2) <= 1 Integer
# 0 <= xim(777,3) <= 1 Integer
# 0 <= xim(778,2) <= 1 Integer
# 0 <= xim(778,3) <= 1 Integer
# 0 <= xim(779,2) <= 1 Integer
# 0 <= xim(779,3) <= 1 Integer
# 0 <= xim(780,2) <= 1 Integer
# 0 <= xim(780,3) <= 1 Integer
# 0 <= xim(781,2) <= 1 Integer
# 0 <= xim(781,3) <= 1 Integer
# 0 <= xim(782,2) <= 1 Integer
# 0 <= xim(782,3) <= 1 Integer
# 0 <= xim(783,2) <= 1 Integer
# 0 <= xim(783,3) <= 1 Integer
# 0 <= xim(784,2) <= 1 Integer
# 0 <= xim(784,3) <= 1 Integer
# 0 <= xim(785,2) <= 1 Integer
# 0 <= xim(785,3) <= 1 Integer
# 0 <= xim(786,2) <= 1 Integer
# 0 <= xim(786,3) <= 1 Integer
# 0 <= xim(787,2) <= 1 Integer
# 0 <= xim(787,3) <= 1 Integer
# 0 <= xim(788,2) <= 1 Integer
# 0 <= xim(788,3) <= 1 Integer
# 0 <= xim(789,2) <= 1 Integer
# 0 <= xim(789,3) <= 1 Integer
# 0 <= xim(790,2) <= 1 Integer
# 0 <= xim(790,3) <= 1 Integer
# 0 <= xim(791,2) <= 1 Integer
# 0 <= xim(791,3) <= 1 Integer
# 0 <= xim(792,2) <= 1 Integer
# 0 <= xim(792,3) <= 1 Integer
# 0 <= xim(793,2) <= 1 Integer
# 0 <= xim(793,3) <= 1 Integer
# 0 <= xim(794,2) <= 1 Integer
# 0 <= xim(794,3) <= 1 Integer
# 0 <= xim(795,2) <= 1 Integer
# 0 <= xim(795,3) <= 1 Integer
# 0 <= xim(796,2) <= 1 Integer
# 0 <= xim(796,3) <= 1 Integer
# 0 <= xim(797,2) <= 1 Integer
# 0 <= xim(797,3) <= 1 Integer
# 0 <= xim(798,2) <= 1 Integer
# 0 <= xim(798,3) <= 1 Integer
# 0 <= xim(799,2) <= 1 Integer
# 0 <= xim(799,3) <= 1 Integer
# 0 <= xim(800,2) <= 1 Integer
# 0 <= xim(800,3) <= 1 Integer
# 0 <= xim(801,2) <= 1 Integer
# 0 <= xim(801,3) <= 1 Integer
# 0 <= xim(802,2) <= 1 Integer
# 0 <= xim(802,3) <= 1 Integer
# 0 <= xim(803,2) <= 1 Integer
# 0 <= xim(803,3) <= 1 Integer
# 0 <= xim(804,2) <= 1 Integer
# 0 <= xim(804,3) <= 1 Integer
# 0 <= xim(805,2) <= 1 Integer
# 0 <= xim(805,3) <= 1 Integer
# 0 <= xim(806,2) <= 1 Integer
# 0 <= xim(806,3) <= 1 Integer
# 0 <= xim(807,2) <= 1 Integer
# 0 <= xim(807,3) <= 1 Integer
# 0 <= xim(808,2) <= 1 Integer
# 0 <= xim(808,3) <= 1 Integer
# 0 <= xim(809,2) <= 1 Integer
# 0 <= xim(809,3) <= 1 Integer
# 0 <= xim(810,2) <= 1 Integer
# 0 <= xim(810,3) <= 1 Integer
# 0 <= xim(811,2) <= 1 Integer
# 0 <= xim(811,3) <= 1 Integer
# 0 <= xim(812,2) <= 1 Integer
# 0 <= xim(812,3) <= 1 Integer
# 0 <= xim(813,2) <= 1 Integer
# 0 <= xim(813,3) <= 1 Integer
# 0 <= xim(814,2) <= 1 Integer
# 0 <= xim(814,3) <= 1 Integer
# 0 <= xim(815,2) <= 1 Integer
# 0 <= xim(815,3) <= 1 Integer
# 0 <= xim(816,2) <= 1 Integer
# 0 <= xim(816,3) <= 1 Integer
# 0 <= xim(817,2) <= 1 Integer
# 0 <= xim(817,3) <= 1 Integer
# 0 <= xim(818,2) <= 1 Integer
# 0 <= xim(818,3) <= 1 Integer
# 0 <= xim(819,2) <= 1 Integer
# 0 <= xim(819,3) <= 1 Integer
# 0 <= xim(820,2) <= 1 Integer
# 0 <= xim(820,3) <= 1 Integer
# 0 <= xim(821,2) <= 1 Integer
# 0 <= xim(821,3) <= 1 Integer
# 0 <= xim(822,2) <= 1 Integer
# 0 <= xim(822,3) <= 1 Integer
# 0 <= xim(823,2) <= 1 Integer
# 0 <= xim(823,3) <= 1 Integer
# 0 <= xim(824,2) <= 1 Integer
# 0 <= xim(824,3) <= 1 Integer
# 0 <= xim(825,2) <= 1 Integer
# 0 <= xim(825,3) <= 1 Integer
# 0 <= xim(826,2) <= 1 Integer
# 0 <= xim(826,3) <= 1 Integer
# 0 <= xim(827,2) <= 1 Integer
# 0 <= xim(827,3) <= 1 Integer
# 0 <= xim(828,2) <= 1 Integer
# 0 <= xim(828,3) <= 1 Integer
# 0 <= xim(829,2) <= 1 Integer
# 0 <= xim(829,3) <= 1 Integer
# 0 <= xim(830,2) <= 1 Integer
# 0 <= xim(830,3) <= 1 Integer
# 0 <= xim(831,2) <= 1 Integer
# 0 <= xim(831,3) <= 1 Integer
# 0 <= xim(832,2) <= 1 Integer
# 0 <= xim(832,3) <= 1 Integer
# 0 <= xim(833,2) <= 1 Integer
# 0 <= xim(833,3) <= 1 Integer
# 0 <= xim(834,2) <= 1 Integer
# 0 <= xim(834,3) <= 1 Integer
# 0 <= xim(835,2) <= 1 Integer
# 0 <= xim(835,3) <= 1 Integer
# 0 <= xim(836,2) <= 1 Integer
# 0 <= xim(836,3) <= 1 Integer
# 0 <= xim(837,2) <= 1 Integer
# 0 <= xim(837,3) <= 1 Integer
# 0 <= xim(838,2) <= 1 Integer
# 0 <= xim(838,3) <= 1 Integer
# 0 <= xim(839,2) <= 1 Integer
# 0 <= xim(839,3) <= 1 Integer
# 0 <= xim(840,2) <= 1 Integer
# 0 <= xim(840,3) <= 1 Integer
# 0 <= xim(841,2) <= 1 Integer
# 0 <= xim(841,3) <= 1 Integer
# 0 <= xim(842,2) <= 1 Integer
# 0 <= xim(842,3) <= 1 Integer
# 0 <= xim(843,2) <= 1 Integer
# 0 <= xim(843,3) <= 1 Integer
# 0 <= xim(844,2) <= 1 Integer
# 0 <= xim(844,3) <= 1 Integer
# 0 <= xim(845,2) <= 1 Integer
# 0 <= xim(845,3) <= 1 Integer
# 0 <= xim(846,2) <= 1 Integer
# 0 <= xim(846,3) <= 1 Integer
# 0 <= xim(847,2) <= 1 Integer
# 0 <= xim(847,3) <= 1 Integer
# 0 <= xim(848,2) <= 1 Integer
# 0 <= xim(848,3) <= 1 Integer
# 0 <= xim(849,2) <= 1 Integer
# 0 <= xim(849,3) <= 1 Integer
# 0 <= xim(850,2) <= 1 Integer
# 0 <= xim(850,3) <= 1 Integer
# 0 <= xim(851,2) <= 1 Integer
# 0 <= xim(851,3) <= 1 Integer
# 0 <= xim(852,2) <= 1 Integer
# 0 <= xim(852,3) <= 1 Integer
# 0 <= xim(853,2) <= 1 Integer
# 0 <= xim(853,3) <= 1 Integer
# 0 <= xim(854,2) <= 1 Integer
# 0 <= xim(854,3) <= 1 Integer
# 0 <= xim(855,2) <= 1 Integer
# 0 <= xim(855,3) <= 1 Integer
# 0 <= xim(856,2) <= 1 Integer
# 0 <= xim(856,3) <= 1 Integer
# 0 <= xim(857,2) <= 1 Integer
# 0 <= xim(857,3) <= 1 Integer
# 0 <= xim(858,2) <= 1 Integer
# 0 <= xim(858,3) <= 1 Integer
# 0 <= xim(859,2) <= 1 Integer
# 0 <= xim(859,3) <= 1 Integer
# 0 <= xim(860,2) <= 1 Integer
# 0 <= xim(860,3) <= 1 Integer
# 0 <= xim(861,2) <= 1 Integer
# 0 <= xim(861,3) <= 1 Integer
# 0 <= xim(862,2) <= 1 Integer
# 0 <= xim(862,3) <= 1 Integer
# 0 <= xim(863,2) <= 1 Integer
# 0 <= xim(863,3) <= 1 Integer
# 0 <= xim(864,2) <= 1 Integer
# 0 <= xim(864,3) <= 1 Integer
# 0 <= xim(865,2) <= 1 Integer
# 0 <= xim(865,3) <= 1 Integer
# 0 <= xim(866,2) <= 1 Integer
# 0 <= xim(866,3) <= 1 Integer
# 0 <= xim(867,2) <= 1 Integer
# 0 <= xim(867,3) <= 1 Integer
# 0 <= xim(868,2) <= 1 Integer
# 0 <= xim(868,3) <= 1 Integer
# 0 <= xim(869,2) <= 1 Integer
# 0 <= xim(869,3) <= 1 Integer
# 0 <= xim(870,2) <= 1 Integer
# 0 <= xim(870,3) <= 1 Integer
# 0 <= xim(871,2) <= 1 Integer
# 0 <= xim(871,3) <= 1 Integer
# 0 <= xim(872,2) <= 1 Integer
# 0 <= xim(872,3) <= 1 Integer
# 0 <= xim(873,2) <= 1 Integer
# 0 <= xim(873,3) <= 1 Integer
# 0 <= xim(874,2) <= 1 Integer
# 0 <= xim(874,3) <= 1 Integer
# 0 <= xim(875,2) <= 1 Integer
# 0 <= xim(875,3) <= 1 Integer
# 0 <= xim(876,2) <= 1 Integer
# 0 <= xim(876,3) <= 1 Integer
# 0 <= xim(877,2) <= 1 Integer
# 0 <= xim(877,3) <= 1 Integer
# 0 <= xim(878,2) <= 1 Integer
# 0 <= xim(878,3) <= 1 Integer
# 0 <= xim(879,2) <= 1 Integer
# 0 <= xim(879,3) <= 1 Integer
# 0 <= xim(880,2) <= 1 Integer
# 0 <= xim(880,3) <= 1 Integer
# 0 <= xim(881,2) <= 1 Integer
# 0 <= xim(881,3) <= 1 Integer
# 0 <= xim(882,2) <= 1 Integer
# 0 <= xim(882,3) <= 1 Integer
# 0 <= xim(883,2) <= 1 Integer
# 0 <= xim(883,3) <= 1 Integer
# 0 <= xim(884,2) <= 1 Integer
# 0 <= xim(884,3) <= 1 Integer
# 0 <= xim(885,2) <= 1 Integer
# 0 <= xim(885,3) <= 1 Integer
# 0 <= xim(886,2) <= 1 Integer
# 0 <= xim(886,3) <= 1 Integer
# 0 <= xim(887,2) <= 1 Integer
# 0 <= xim(887,3) <= 1 Integer
# 0 <= xim(888,2) <= 1 Integer
# 0 <= xim(888,3) <= 1 Integer
# 0 <= xim(889,2) <= 1 Integer
# 0 <= xim(889,3) <= 1 Integer
# 0 <= xim(890,2) <= 1 Integer
# 0 <= xim(890,3) <= 1 Integer
# 0 <= xim(891,2) <= 1 Integer
# 0 <= xim(891,3) <= 1 Integer
# 0 <= xim(892,2) <= 1 Integer
# 0 <= xim(892,3) <= 1 Integer
# 0 <= xim(893,2) <= 1 Integer
# 0 <= xim(893,3) <= 1 Integer
# 0 <= xim(894,2) <= 1 Integer
# 0 <= xim(894,3) <= 1 Integer
# 0 <= xim(895,2) <= 1 Integer
# 0 <= xim(895,3) <= 1 Integer
# 0 <= xim(896,2) <= 1 Integer
# 0 <= xim(896,3) <= 1 Integer
# 0 <= xim(897,2) <= 1 Integer
# 0 <= xim(897,3) <= 1 Integer
# 0 <= xim(898,2) <= 1 Integer
# 0 <= xim(898,3) <= 1 Integer
# 0 <= xim(899,2) <= 1 Integer
# 0 <= xim(899,3) <= 1 Integer
# 0 <= xim(900,2) <= 1 Integer
# 0 <= xim(900,3) <= 1 Integer
# 0 <= xim(901,2) <= 1 Integer
# 0 <= xim(901,3) <= 1 Integer
# 0 <= xim(902,2) <= 1 Integer
# 0 <= xim(902,3) <= 1 Integer
# 0 <= xim(903,2) <= 1 Integer
# 0 <= xim(903,3) <= 1 Integer
# 0 <= xim(904,2) <= 1 Integer
# 0 <= xim(904,3) <= 1 Integer
# 0 <= xim(905,2) <= 1 Integer
# 0 <= xim(905,3) <= 1 Integer
# 0 <= xim(906,2) <= 1 Integer
# 0 <= xim(906,3) <= 1 Integer
# 0 <= xim(907,2) <= 1 Integer
# 0 <= xim(907,3) <= 1 Integer
# 0 <= xim(908,2) <= 1 Integer
# 0 <= xim(908,3) <= 1 Integer
# 0 <= xim(909,2) <= 1 Integer
# 0 <= xim(909,3) <= 1 Integer
# 0 <= xim(910,2) <= 1 Integer
# 0 <= xim(910,3) <= 1 Integer
# 0 <= xim(911,2) <= 1 Integer
# 0 <= xim(911,3) <= 1 Integer
# 0 <= xim(912,2) <= 1 Integer
# 0 <= xim(912,3) <= 1 Integer
# 0 <= xim(913,2) <= 1 Integer
# 0 <= xim(913,3) <= 1 Integer
# 0 <= xim(914,2) <= 1 Integer
# 0 <= xim(914,3) <= 1 Integer
# 0 <= xim(915,2) <= 1 Integer
# 0 <= xim(915,3) <= 1 Integer
# 0 <= xim(916,2) <= 1 Integer
# 0 <= xim(916,3) <= 1 Integer
# 0 <= xim(917,2) <= 1 Integer
# 0 <= xim(917,3) <= 1 Integer
# 0 <= xim(918,2) <= 1 Integer
# 0 <= xim(918,3) <= 1 Integer
# 0 <= xim(919,2) <= 1 Integer
# 0 <= xim(919,3) <= 1 Integer
# 0 <= xim(920,2) <= 1 Integer
# 0 <= xim(920,3) <= 1 Integer
# 0 <= xim(921,2) <= 1 Integer
# 0 <= xim(921,3) <= 1 Integer
# 0 <= xim(922,2) <= 1 Integer
# 0 <= xim(922,3) <= 1 Integer
# 0 <= xim(923,2) <= 1 Integer
# 0 <= xim(923,3) <= 1 Integer
# 0 <= xim(924,2) <= 1 Integer
# 0 <= xim(924,3) <= 1 Integer
# 0 <= xim(925,2) <= 1 Integer
# 0 <= xim(925,3) <= 1 Integer
# 0 <= xim(926,2) <= 1 Integer
# 0 <= xim(926,3) <= 1 Integer
# 0 <= xim(927,2) <= 1 Integer
# 0 <= xim(927,3) <= 1 Integer
# 0 <= xim(928,2) <= 1 Integer
# 0 <= xim(928,3) <= 1 Integer
# 0 <= xim(929,2) <= 1 Integer
# 0 <= xim(929,3) <= 1 Integer
# 0 <= xim(930,2) <= 1 Integer
# 0 <= xim(930,3) <= 1 Integer
# 0 <= xim(931,2) <= 1 Integer
# 0 <= xim(931,3) <= 1 Integer
# 0 <= xim(932,2) <= 1 Integer
# 0 <= xim(932,3) <= 1 Integer
# 0 <= xim(933,2) <= 1 Integer
# 0 <= xim(933,3) <= 1 Integer
# 0 <= xim(934,2) <= 1 Integer
# 0 <= xim(934,3) <= 1 Integer
# 0 <= xim(935,2) <= 1 Integer
# 0 <= xim(935,3) <= 1 Integer
# 0 <= xim(936,2) <= 1 Integer
# 0 <= xim(936,3) <= 1 Integer
# 0 <= xim(937,2) <= 1 Integer
# 0 <= xim(937,3) <= 1 Integer
# 0 <= xim(938,2) <= 1 Integer
# 0 <= xim(938,3) <= 1 Integer
# 0 <= xim(939,2) <= 1 Integer
# 0 <= xim(939,3) <= 1 Integer
# 0 <= xim(940,2) <= 1 Integer
# 0 <= xim(940,3) <= 1 Integer
# 0 <= xim(941,2) <= 1 Integer
# 0 <= xim(941,3) <= 1 Integer
# 0 <= xim(942,2) <= 1 Integer
# 0 <= xim(942,3) <= 1 Integer
# 0 <= xim(943,2) <= 1 Integer
# 0 <= xim(943,3) <= 1 Integer
# 0 <= xim(944,2) <= 1 Integer
# 0 <= xim(944,3) <= 1 Integer
# 0 <= xim(945,2) <= 1 Integer
# 0 <= xim(945,3) <= 1 Integer
# 0 <= xim(946,2) <= 1 Integer
# 0 <= xim(946,3) <= 1 Integer
# 0 <= xim(947,2) <= 1 Integer
# 0 <= xim(947,3) <= 1 Integer
# 0 <= xim(948,2) <= 1 Integer
# 0 <= xim(948,3) <= 1 Integer
# 0 <= xim(949,2) <= 1 Integer
# 0 <= xim(949,3) <= 1 Integer
# 0 <= xim(950,2) <= 1 Integer
# 0 <= xim(950,3) <= 1 Integer
# 0 <= xim(951,2) <= 1 Integer
# 0 <= xim(951,3) <= 1 Integer
# 0 <= xim(952,2) <= 1 Integer
# 0 <= xim(952,3) <= 1 Integer
# 0 <= xim(953,2) <= 1 Integer
# 0 <= xim(953,3) <= 1 Integer
# 0 <= xim(954,2) <= 1 Integer
# 0 <= xim(954,3) <= 1 Integer
# 0 <= xim(955,2) <= 1 Integer
# 0 <= xim(955,3) <= 1 Integer
# 0 <= xim(956,2) <= 1 Integer
# 0 <= xim(956,3) <= 1 Integer
# 0 <= xim(957,2) <= 1 Integer
# 0 <= xim(957,3) <= 1 Integer
# 0 <= xim(958,2) <= 1 Integer
# 0 <= xim(958,3) <= 1 Integer
# 0 <= xim(959,2) <= 1 Integer
# 0 <= xim(959,3) <= 1 Integer
# 0 <= xim(960,2) <= 1 Integer
# 0 <= xim(960,3) <= 1 Integer
# 0 <= xim(961,2) <= 1 Integer
# 0 <= xim(961,3) <= 1 Integer
# 0 <= xim(962,2) <= 1 Integer
# 0 <= xim(962,3) <= 1 Integer
# 0 <= xim(963,2) <= 1 Integer
# 0 <= xim(963,3) <= 1 Integer
# 0 <= xim(964,2) <= 1 Integer
# 0 <= xim(964,3) <= 1 Integer
# 0 <= xim(965,2) <= 1 Integer
# 0 <= xim(965,3) <= 1 Integer
# 0 <= xim(966,2) <= 1 Integer
# 0 <= xim(966,3) <= 1 Integer
# 0 <= xim(967,2) <= 1 Integer
# 0 <= xim(967,3) <= 1 Integer
# 0 <= xim(968,2) <= 1 Integer
# 0 <= xim(968,3) <= 1 Integer
# 0 <= xim(969,2) <= 1 Integer
# 0 <= xim(969,3) <= 1 Integer
# 0 <= xim(970,2) <= 1 Integer
# 0 <= xim(970,3) <= 1 Integer
# 0 <= xim(971,2) <= 1 Integer
# 0 <= xim(971,3) <= 1 Integer
# 0 <= xim(972,2) <= 1 Integer
# 0 <= xim(972,3) <= 1 Integer
# 0 <= xim(973,2) <= 1 Integer
# 0 <= xim(973,3) <= 1 Integer
# 0 <= xim(974,2) <= 1 Integer
# 0 <= xim(974,3) <= 1 Integer
# 0 <= xim(975,2) <= 1 Integer
# 0 <= xim(975,3) <= 1 Integer
# 0 <= xim(976,2) <= 1 Integer
# 0 <= xim(976,3) <= 1 Integer
# 0 <= xim(977,2) <= 1 Integer
# 0 <= xim(977,3) <= 1 Integer
# 0 <= xim(978,2) <= 1 Integer
# 0 <= xim(978,3) <= 1 Integer
# 0 <= xim(979,2) <= 1 Integer
# 0 <= xim(979,3) <= 1 Integer
# 0 <= xim(980,2) <= 1 Integer
# 0 <= xim(980,3) <= 1 Integer
# 0 <= xim(981,2) <= 1 Integer
# 0 <= xim(981,3) <= 1 Integer
# 0 <= xim(982,2) <= 1 Integer
# 0 <= xim(982,3) <= 1 Integer
# 0 <= xim(983,2) <= 1 Integer
# 0 <= xim(983,3) <= 1 Integer
# 0 <= xim(984,2) <= 1 Integer
# 0 <= xim(984,3) <= 1 Integer
# 0 <= xim(985,2) <= 1 Integer
# 0 <= xim(985,3) <= 1 Integer
# 0 <= xim(986,2) <= 1 Integer
# 0 <= xim(986,3) <= 1 Integer
# 0 <= xim(987,2) <= 1 Integer
# 0 <= xim(987,3) <= 1 Integer
# 0 <= xim(988,2) <= 1 Integer
# 0 <= xim(988,3) <= 1 Integer
# 0 <= xim(989,2) <= 1 Integer
# 0 <= xim(989,3) <= 1 Integer
# 0 <= xim(990,2) <= 1 Integer
# 0 <= xim(990,3) <= 1 Integer
# 0 <= xim(991,2) <= 1 Integer
# 0 <= xim(991,3) <= 1 Integer
# 0 <= xim(992,2) <= 1 Integer
# 0 <= xim(992,3) <= 1 Integer
# 0 <= xim(993,2) <= 1 Integer
# 0 <= xim(993,3) <= 1 Integer
# 0 <= xim(994,2) <= 1 Integer
# 0 <= xim(994,3) <= 1 Integer
# 0 <= xim(995,2) <= 1 Integer
# 0 <= xim(995,3) <= 1 Integer
# 0 <= xim(996,2) <= 1 Integer
# 0 <= xim(996,3) <= 1 Integer
# 0 <= xim(997,2) <= 1 Integer
# 0 <= xim(997,3) <= 1 Integer
# 0 <= xim(998,2) <= 1 Integer
# 0 <= xim(998,3) <= 1 Integer
# 0 <= xim(999,2) <= 1 Integer
# 0 <= xim(999,3) <= 1 Integer

# %%
start = time.time()
status = m.solve()
end = time.time()

# %%
print(f'Status: {LpStatus[status]}')
print(f'Result: {value(m.objective):.02f}')
print(f'Time: {end - start:.02f} [sec]')
# Out:
# Status: Optimal
# Result: 326.09
# Time: 5.56 [sec]

# %%
send_dm_df = pd.DataFrame([[xim[id, dm].value() for dm in DM] for id in ID], columns=['send_dm1', 'send_dm2', 'send_dm3'])
cust_send_df = pd.concat([c_df[['customer_id', 'age_cat', 'freq_cat']], send_dm_df], axis=1)
cust_send_df.head()
# Out:
#    customer_id   age_cat freq_cat  send_dm1  send_dm2  send_dm3
# 0            1  age20~34    freq2       0.0       1.0       0.0
# 1            2  age35~49    freq0       0.0       1.0       0.0
# 2            3  age35~49    freq0       0.0       1.0       0.0
# 3            4    age~19    freq0       0.0       1.0       0.0
# 4            5  age35~49    freq0       0.0       1.0       0.0

# %%
fig, axs = plt.subplots(1, 3, figsize=(20, 3))
for i, ptn in enumerate(['send_dm1', 'send_dm2', 'send_dm3']):
    pivot_df = pd.pivot_table(data=cust_send_df, values=ptn, columns='freq_cat', index='age_cat', aggfunc='mean')
    pivot_df = pivot_df.reindex(['age~19', 'age20~34', 'age35~49', 'age50~'])
    sns.heatmap(pivot_df, vmin=0, vmax=1, annot=True, fmt='.1%', cmap='Blues', ax=axs[i])
    axs[i].set_title(f'{ptn}_rate')

fig, axs = plt.subplots(1, 3, figsize=(20, 3))
for i, ptn in enumerate(['send_dm1', 'send_dm2', 'send_dm3']):
    pivot_df = pd.pivot_table(data=cust_send_df, values=ptn, columns='freq_cat', index='age_cat', aggfunc='sum')
    pivot_df = pivot_df.reindex(['age~19', 'age20~34', 'age35~49', 'age50~'])
    sns.heatmap(pivot_df, vmin=0, vmax=1, annot=True, fmt='.0f', cmap='Blues', ax=axs[i])
    axs[i].set_title(f'{ptn}_num')
